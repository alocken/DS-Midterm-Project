# %% [markdown]
# # EDA

# %% [markdown]
# - The os module has a perfect method to list files in a directory.
# - Pandas json normalize could work here but is not necessary to convert the JSON data to a dataframe.
# - You may need a nested for-loop to access each sale!
# - We've put a lot of time into creating the structure of this repository, and it's a good example for future projects.  In the file functions_variables.py, there is an example function that you can import and use.  If you have any variables, functions or classes that you want to make, they can be put in the functions_variables.py file and imported into a notebook.  Note that only .py files can be imported into a notebook. If you want to import everything from a .py file, you can use the following:
# ```python
# from functions_variables import *
# ```
# If you just import functions_variables, then each object from the file will need to be prepended with "functions_variables"\
# Using this .py file will keep your notebooks very organized and make it easier to reuse code between notebooks.

# %%
import pandas as pd
import numpy as np
import os
import json
from pprint import pprint
from functions_variables import encode_tags
from collections import Counter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 6
#       4 import json
#       5 from pprint import pprint
# ----> 6 from functions_variables import encode_tags
#       7 from collections import Counter
#
# ImportError: cannot import name 'encode_tags' from 'functions_variables' (/Users/leticiamichalishen/Desktop/DS-Midterm-Project/notebooks/functions_variables.py)

# %% [markdown]
# ## Data Importing

# %%
# load one file first to see what type of data and attributes
with open('../data/AK_Juneau_0.json', 'r') as f:
    data = json.load(f)

# %%
print(type(data))         # one file attribute
print(data.keys())        # top-level keys
# Out:
# <class 'dict'>
# dict_keys(['status', 'data'])

# %%
# load json object
with open('../data/AK_Juneau_0.json') as f:
    nested_json = json.load(f)

# print only the first 2 key-value pairs
for i, (key, value) in enumerate(nested_json.items()):
    if i >= 2:
        break
    print(json.dumps({key: value}, indent=2))
# Out:
# {
#   "status": 200
# }
# {
#   "data": {
#     "total": 8,
#     "count": 8,
#     "results": [
#       {
#         "primary_photo": {
#           "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#         },
#         "last_update_date": "2023-09-19T20:52:50Z",
#         "source": {
#           "plan_id": null,
#           "agents": [
#             {
#               "office_name": "EXP Realty LLC - Southeast Alaska"
#             },
#             {
#               "office_name": "Non-Member Office"
#             }
#           ],
#           "spec_id": null,
#           "type": "mls"
#         },
#         "tags": [
#           "carport",
#           "community_outdoor_space",
#           "cul_de_sac",
#           "family_room",
#           "hardwood_floors",
#           "hill_or_mountain_view",
#           "recreation_facilities",
#           "rv_or_boat_parking",
#           "basement",
#           "garage_1_or_more",
#           "two_or_more_stories",
#           "big_yard",
#           "high_ceiling",
#           "efficient",
#           "trails",
#           "shopping"
#         ],
#         "permalink": "9453-Herbert-Pl_Juneau_AK_99801_M90744-30767",
#         "status": "sold",
#         "list_date": "2023-06-29T21:16:25.000000Z",
#         "open_houses": null,
#         "description": {
#           "year_built": 1963,
#           "baths_3qtr": null,
#           "sold_date": "2023-09-18",
#           "sold_price": null,
#           "baths_full": 2,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": 10454,
#           "sqft": 1821,
#           "baths": 2,
#           "sub_type": null,
#           "baths_1qtr": null,
#           "garage": 1,
#           "stories": null,
#           "beds": 3,
#           "type": "single_family"
#         },
#         "branding": [
#           {
#             "name": "EXP Realty LLC - Southeast Alaska",
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": 554950,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "9074430767",
#         "photos": [
#           {
#             "tags": [
#               {
#                 "label": "house_view",
#                 "probability": 0.9931892156601
#               },
#               {
#                 "label": "road_view",
#                 "probability": 0.84215885400772
#               },
#               {
#                 "label": "house_view",
#                 "probability": 0.93829786777496
#               }
#             ],
#             "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#           },
#           {
#             "tags": [
#               {
#                 "label": "living_room",
#                 "probability": 0.99856203794479
#               }
#             ],
#             "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2021977128s-w1024_h768.jpg"
#           },
#           {
#             "tags": [
#               {
#                 "label": "dining_room",
#                 "probability": 0.99998116493225
#               }
#             ],
#             "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2832281708s-w1024_h768.jpg"
#           },
#           {
#             "tags": [
#               {
#                 "label": "unknown",
#                 "probability": 0.91968685388565
#               }
#             ],
#             "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2250208436s-w1024_h768.jpg"
#           },
#           {
#             "tags": [
#               {
#                 "label": "kitchen",
#                 "probability": 0.99999892711639
#               }
#             ],
#             "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m4264543754s-w1024_h768.jpg"
#           }
#         ],
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": false,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": false
#         },
#         "community": null,
#         "products": {
#           "brand_name": "basic_opt_in"
#         },
#         "virtual_tours": null,
#         "other_listings": {
#           "rdc": [
#             {
#               "listing_id": "2957241843",
#               "listing_key": null,
#               "status": "sold",
#               "primary": true
#             },
#             {
#               "listing_id": "2957022863",
#               "listing_key": null,
#               "status": "off_market",
#               "primary": null
#             }
#           ]
#         },
#         "listing_id": "2957241843",
#         "price_reduced_amount": 45000,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": {
#               "lon": -134.59372,
#               "lat": 58.36395
#             },
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "9453 Herbert Pl"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9453%20Herbert%20Pl%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=OPv224SjFIJWgVKAXZKZXNYEdNQ=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       },
#       {
#         "primary_photo": null,
#         "last_update_date": null,
#         "source": null,
#         "tags": null,
#         "permalink": "8477-Thunder-Mountain-Rd_Juneau_AK_99801_M94249-83842",
#         "status": "sold",
#         "list_date": null,
#         "open_houses": null,
#         "description": {
#           "year_built": null,
#           "baths_3qtr": null,
#           "sold_date": "2023-08-22",
#           "sold_price": null,
#           "baths_full": null,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": null,
#           "sqft": null,
#           "baths": null,
#           "sub_type": null,
#           "baths_1qtr": null,
#           "garage": null,
#           "stories": null,
#           "beds": null,
#           "type": null
#         },
#         "branding": [
#           {
#             "name": null,
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": null,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "9424983842",
#         "photos": null,
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": null,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": null
#         },
#         "community": null,
#         "products": null,
#         "virtual_tours": null,
#         "other_listings": {
#           "rdc": [
#             {
#               "listing_id": "2958935271",
#               "listing_key": null,
#               "status": "sold",
#               "primary": null
#             }
#           ]
#         },
#         "listing_id": null,
#         "price_reduced_amount": null,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": null,
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "8477 Thunder Mountain Rd"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8477%20Thunder%20Mountain%20Rd%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=X_IwZxbWaAsrSLHsERLq_64YJhc=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       },
#       {
#         "primary_photo": null,
#         "last_update_date": null,
#         "source": null,
#         "tags": null,
#         "permalink": "4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516",
#         "status": "sold",
#         "list_date": null,
#         "open_houses": null,
#         "description": {
#           "year_built": null,
#           "baths_3qtr": null,
#           "sold_date": "2023-08-22",
#           "sold_price": null,
#           "baths_full": null,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": null,
#           "sqft": null,
#           "baths": null,
#           "sub_type": null,
#           "baths_1qtr": null,
#           "garage": null,
#           "stories": null,
#           "beds": null,
#           "type": null
#         },
#         "branding": [
#           {
#             "name": null,
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": null,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "9479068516",
#         "photos": null,
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": null,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": null
#         },
#         "community": null,
#         "products": null,
#         "virtual_tours": null,
#         "other_listings": {
#           "rdc": [
#             {
#               "listing_id": "2958935192",
#               "listing_key": null,
#               "status": "sold",
#               "primary": null
#             }
#           ]
#         },
#         "listing_id": null,
#         "price_reduced_amount": null,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": null,
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "4515 Glacier Hwy"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4515%20Glacier%20Hwy%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=ql3QFXXYvrKARTE42MC9p2Egtdg=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       },
#       {
#         "primary_photo": null,
#         "last_update_date": null,
#         "source": null,
#         "tags": null,
#         "permalink": "17850-Point-Stephens-Rd_Juneau_AK_99801_M98793-31943",
#         "status": "sold",
#         "list_date": null,
#         "open_houses": null,
#         "description": {
#           "year_built": null,
#           "baths_3qtr": null,
#           "sold_date": "2023-08-21",
#           "sold_price": null,
#           "baths_full": null,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": null,
#           "sqft": null,
#           "baths": null,
#           "sub_type": null,
#           "baths_1qtr": null,
#           "garage": null,
#           "stories": null,
#           "beds": null,
#           "type": null
#         },
#         "branding": [
#           {
#             "name": null,
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": null,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "9879331943",
#         "photos": null,
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": null,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": null
#         },
#         "community": null,
#         "products": null,
#         "virtual_tours": null,
#         "other_listings": {
#           "rdc": [
#             {
#               "listing_id": "2958925235",
#               "listing_key": null,
#               "status": "sold",
#               "primary": null
#             }
#           ]
#         },
#         "listing_id": null,
#         "price_reduced_amount": null,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": null,
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "17850 Point Stephens Rd"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=17850%20Point%20Stephens%20Rd%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=sSYpYLhHnOQYJTloXVnGAmy2ydY=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       },
#       {
#         "primary_photo": null,
#         "last_update_date": null,
#         "source": null,
#         "tags": null,
#         "permalink": "9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99801_M95216-39574",
#         "status": "sold",
#         "list_date": null,
#         "open_houses": null,
#         "description": {
#           "year_built": null,
#           "baths_3qtr": null,
#           "sold_date": "2023-08-21",
#           "sold_price": null,
#           "baths_full": null,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": null,
#           "sqft": null,
#           "baths": null,
#           "sub_type": null,
#           "baths_1qtr": null,
#           "garage": null,
#           "stories": null,
#           "beds": null,
#           "type": null
#         },
#         "branding": [
#           {
#             "name": null,
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": null,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "9521639574",
#         "photos": null,
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": null,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": null
#         },
#         "community": null,
#         "products": null,
#         "virtual_tours": null,
#         "other_listings": {
#           "rdc": [
#             {
#               "listing_id": "2958924367",
#               "listing_key": null,
#               "status": "sold",
#               "primary": null
#             }
#           ]
#         },
#         "listing_id": null,
#         "price_reduced_amount": null,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": null,
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "9951 Stephen Richards Memorial Dr"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9951%20Stephen%20Richards%20Memorial%20Dr%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=al_a0xZ7J3DLCuNg4YDdfq3TZKE=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       },
#       {
#         "primary_photo": null,
#         "last_update_date": "2023-08-04T22:49:14Z",
#         "source": {
#           "plan_id": null,
#           "agents": [
#             {
#               "office_name": "Platinum Keller Williams Realty Alaska Group"
#             },
#             {
#               "office_name": "Platinum Keller Williams Realty Alaska Group"
#             }
#           ],
#           "spec_id": null,
#           "type": "mls"
#         },
#         "tags": [
#           "carport",
#           "hill_or_mountain_view",
#           "ocean_view",
#           "single_story",
#           "waterfront",
#           "open_floor_plan",
#           "floor_plan",
#           "rental_property",
#           "furniture",
#           "new_roof",
#           "beach"
#         ],
#         "permalink": "11909-Glacier-Hwy-Apt-105_Juneau_AK_99801_M74123-09719",
#         "status": "sold",
#         "list_date": "2023-08-21T21:01:22.000000Z",
#         "open_houses": null,
#         "description": {
#           "year_built": 1969,
#           "baths_3qtr": null,
#           "sold_date": "2023-08-04",
#           "sold_price": null,
#           "baths_full": 1,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": null,
#           "sqft": 950,
#           "baths": 1,
#           "sub_type": "condo",
#           "baths_1qtr": null,
#           "garage": null,
#           "stories": null,
#           "beds": 2,
#           "type": "condos"
#         },
#         "branding": [
#           {
#             "name": "Platinum Keller Williams Realty Alaska Group",
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": 415000,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "7412309719",
#         "photos": null,
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": null,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": false
#         },
#         "community": null,
#         "products": {
#           "brand_name": "basic_opt_in"
#         },
#         "virtual_tours": null,
#         "other_listings": {
#           "rdc": [
#             {
#               "listing_id": "2958925334",
#               "listing_key": null,
#               "status": "sold",
#               "primary": null
#             }
#           ]
#         },
#         "listing_id": "2958925334",
#         "price_reduced_amount": null,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": {
#               "lon": -134.649067,
#               "lat": 58.386651
#             },
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "11909 Glacier Hwy Apt 105"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=11909%20Glacier%20Hwy%20Apt%20105%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=cokn0o0X46-BL_yReSTViMXMYh4=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       },
#       {
#         "primary_photo": null,
#         "last_update_date": "2023-08-04T21:31:44Z",
#         "source": {
#           "plan_id": null,
#           "agents": [
#             {
#               "office_name": "Southeast Alaska Real Estate"
#             },
#             {
#               "office_name": "Platinum Keller Williams Realty Alaska Group"
#             }
#           ],
#           "spec_id": null,
#           "type": "mls"
#         },
#         "tags": [
#           "city_view",
#           "community_outdoor_space",
#           "community_security_features",
#           "corner_lot",
#           "hill_or_mountain_view",
#           "lake_view",
#           "ocean_view",
#           "river_view",
#           "spa_or_hot_tub",
#           "garage_1_or_more",
#           "garage_2_or_more",
#           "two_or_more_stories",
#           "vaulted_ceiling",
#           "media_room",
#           "ensuite",
#           "private_courtyard",
#           "trails"
#         ],
#         "permalink": "808-5th-St_Juneau_AK_99801_M76604-90777",
#         "status": "sold",
#         "list_date": "2023-08-21T21:01:22.000000Z",
#         "open_houses": null,
#         "description": {
#           "year_built": 1920,
#           "baths_3qtr": null,
#           "sold_date": "2023-08-03",
#           "sold_price": null,
#           "baths_full": 3,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": 5875,
#           "sqft": 3860,
#           "baths": 3,
#           "sub_type": null,
#           "baths_1qtr": null,
#           "garage": 2,
#           "stories": null,
#           "beds": 5,
#           "type": "single_family"
#         },
#         "branding": [
#           {
#             "name": "Southeast Alaska Real Estate",
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": 835000,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "7660490777",
#         "photos": null,
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": null,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": false
#         },
#         "community": null,
#         "products": {
#           "brand_name": "essentials"
#         },
#         "virtual_tours": null,
#         "other_listings": {
#           "rdc": [
#             {
#               "listing_id": "2958924095",
#               "listing_key": null,
#               "status": "sold",
#               "primary": null
#             },
#             {
#               "listing_id": "2941727948",
#               "listing_key": null,
#               "status": "off_market",
#               "primary": null
#             },
#             {
#               "listing_id": "2641864483",
#               "listing_key": null,
#               "status": "off_market",
#               "primary": null
#             }
#           ]
#         },
#         "listing_id": "2958924095",
#         "price_reduced_amount": null,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": {
#               "lon": -134.403991,
#               "lat": 58.304573
#             },
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "808 5th St"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=808%205th%20St%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=tV-uGGz9zKJiafcI3GDfgu9GV_I=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       },
#       {
#         "primary_photo": null,
#         "last_update_date": "2023-12-07",
#         "source": null,
#         "tags": null,
#         "permalink": "4446-Trafalgar-Ave_Juneau_AK_99801_M82741-21172",
#         "status": "sold",
#         "list_date": null,
#         "open_houses": null,
#         "description": {
#           "year_built": 2002,
#           "baths_3qtr": null,
#           "sold_date": "2023-07-21",
#           "sold_price": null,
#           "baths_full": 2,
#           "name": null,
#           "baths_half": null,
#           "lot_sqft": 7476,
#           "sqft": 1375,
#           "baths": 2,
#           "sub_type": null,
#           "baths_1qtr": null,
#           "garage": null,
#           "stories": 1,
#           "beds": 3,
#           "type": "mobile"
#         },
#         "branding": [
#           {
#             "name": null,
#             "photo": null,
#             "type": "Office"
#           }
#         ],
#         "list_price": null,
#         "lead_attributes": {
#           "show_contact_an_agent": true
#         },
#         "property_id": "8274121172",
#         "photos": null,
#         "flags": {
#           "is_new_construction": null,
#           "is_for_rent": null,
#           "is_subdivision": null,
#           "is_contingent": null,
#           "is_price_reduced": null,
#           "is_pending": null,
#           "is_foreclosure": null,
#           "is_plan": null,
#           "is_coming_soon": null,
#           "is_new_listing": null
#         },
#         "community": null,
#         "products": null,
#         "virtual_tours": null,
#         "other_listings": null,
#         "listing_id": null,
#         "price_reduced_amount": null,
#         "location": {
#           "address": {
#             "postal_code": "99801",
#             "state": "Alaska",
#             "coordinate": {
#               "lon": -134.553717,
#               "lat": 58.396178
#             },
#             "city": "Juneau",
#             "state_code": "AK",
#             "line": "4446 Trafalgar Ave"
#           },
#           "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4446%20Trafalgar%20Ave%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=V24OM91aZHY5-heG-dKObuuYh4c=",
#           "county": {
#             "fips_code": null,
#             "name": "Juneau"
#           }
#         },
#         "matterport": false
#       }
#     ]
#   }
# }

# %%
# attribute of data
print(type(nested_json))
# Out:
# <class 'dict'>

# %%
# load type of data and attributes of one file

# local JSON file
file_path = '../data/AK_Juneau_0.json'
with open(file_path, 'r') as f:
    data = json.load(f) 
   
# print only the first 2 key-value pairs
for i, (key, value) in enumerate(data.items()):
    if i >= 2:
        break
    print(json.dumps({key: value}, indent=4))

#attribute of data
print(type(data))
# Out:
# {
#     "status": 200
# }
# {
#     "data": {
#         "total": 8,
#         "count": 8,
#         "results": [
#             {
#                 "primary_photo": {
#                     "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#                 },
#                 "last_update_date": "2023-09-19T20:52:50Z",
#                 "source": {
#                     "plan_id": null,
#                     "agents": [
#                         {
#                             "office_name": "EXP Realty LLC - Southeast Alaska"
#                         },
#                         {
#                             "office_name": "Non-Member Office"
#                         }
#                     ],
#                     "spec_id": null,
#                     "type": "mls"
#                 },
#                 "tags": [
#                     "carport",
#                     "community_outdoor_space",
#                     "cul_de_sac",
#                     "family_room",
#                     "hardwood_floors",
#                     "hill_or_mountain_view",
#                     "recreation_facilities",
#                     "rv_or_boat_parking",
#                     "basement",
#                     "garage_1_or_more",
#                     "two_or_more_stories",
#                     "big_yard",
#                     "high_ceiling",
#                     "efficient",
#                     "trails",
#                     "shopping"
#                 ],
#                 "permalink": "9453-Herbert-Pl_Juneau_AK_99801_M90744-30767",
#                 "status": "sold",
#                 "list_date": "2023-06-29T21:16:25.000000Z",
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 1963,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-09-18",
#                     "sold_price": null,
#                     "baths_full": 2,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": 10454,
#                     "sqft": 1821,
#                     "baths": 2,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": 1,
#                     "stories": null,
#                     "beds": 3,
#                     "type": "single_family"
#                 },
#                 "branding": [
#                     {
#                         "name": "EXP Realty LLC - Southeast Alaska",
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": 554950,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9074430767",
#                 "photos": [
#                     {
#                         "tags": [
#                             {
#                                 "label": "house_view",
#                                 "probability": 0.9931892156601
#                             },
#                             {
#                                 "label": "road_view",
#                                 "probability": 0.84215885400772
#                             },
#                             {
#                                 "label": "house_view",
#                                 "probability": 0.93829786777496
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "living_room",
#                                 "probability": 0.99856203794479
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2021977128s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "dining_room",
#                                 "probability": 0.99998116493225
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2832281708s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "unknown",
#                                 "probability": 0.91968685388565
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2250208436s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "kitchen",
#                                 "probability": 0.99999892711639
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m4264543754s-w1024_h768.jpg"
#                     }
#                 ],
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": false,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": false
#                 },
#                 "community": null,
#                 "products": {
#                     "brand_name": "basic_opt_in"
#                 },
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2957241843",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": true
#                         },
#                         {
#                             "listing_id": "2957022863",
#                             "listing_key": null,
#                             "status": "off_market",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": "2957241843",
#                 "price_reduced_amount": 45000,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.59372,
#                             "lat": 58.36395
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "9453 Herbert Pl"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9453%20Herbert%20Pl%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=OPv224SjFIJWgVKAXZKZXNYEdNQ=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "8477-Thunder-Mountain-Rd_Juneau_AK_99801_M94249-83842",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-22",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9424983842",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958935271",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "8477 Thunder Mountain Rd"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8477%20Thunder%20Mountain%20Rd%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=X_IwZxbWaAsrSLHsERLq_64YJhc=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-22",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9479068516",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958935192",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "4515 Glacier Hwy"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4515%20Glacier%20Hwy%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=ql3QFXXYvrKARTE42MC9p2Egtdg=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "17850-Point-Stephens-Rd_Juneau_AK_99801_M98793-31943",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-21",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9879331943",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958925235",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "17850 Point Stephens Rd"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=17850%20Point%20Stephens%20Rd%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=sSYpYLhHnOQYJTloXVnGAmy2ydY=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99801_M95216-39574",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-21",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9521639574",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958924367",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "9951 Stephen Richards Memorial Dr"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9951%20Stephen%20Richards%20Memorial%20Dr%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=al_a0xZ7J3DLCuNg4YDdfq3TZKE=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": "2023-08-04T22:49:14Z",
#                 "source": {
#                     "plan_id": null,
#                     "agents": [
#                         {
#                             "office_name": "Platinum Keller Williams Realty Alaska Group"
#                         },
#                         {
#                             "office_name": "Platinum Keller Williams Realty Alaska Group"
#                         }
#                     ],
#                     "spec_id": null,
#                     "type": "mls"
#                 },
#                 "tags": [
#                     "carport",
#                     "hill_or_mountain_view",
#                     "ocean_view",
#                     "single_story",
#                     "waterfront",
#                     "open_floor_plan",
#                     "floor_plan",
#                     "rental_property",
#                     "furniture",
#                     "new_roof",
#                     "beach"
#                 ],
#                 "permalink": "11909-Glacier-Hwy-Apt-105_Juneau_AK_99801_M74123-09719",
#                 "status": "sold",
#                 "list_date": "2023-08-21T21:01:22.000000Z",
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 1969,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-04",
#                     "sold_price": null,
#                     "baths_full": 1,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": 950,
#                     "baths": 1,
#                     "sub_type": "condo",
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": 2,
#                     "type": "condos"
#                 },
#                 "branding": [
#                     {
#                         "name": "Platinum Keller Williams Realty Alaska Group",
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": 415000,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "7412309719",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": false
#                 },
#                 "community": null,
#                 "products": {
#                     "brand_name": "basic_opt_in"
#                 },
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958925334",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": "2958925334",
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.649067,
#                             "lat": 58.386651
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "11909 Glacier Hwy Apt 105"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=11909%20Glacier%20Hwy%20Apt%20105%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=cokn0o0X46-BL_yReSTViMXMYh4=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": "2023-08-04T21:31:44Z",
#                 "source": {
#                     "plan_id": null,
#                     "agents": [
#                         {
#                             "office_name": "Southeast Alaska Real Estate"
#                         },
#                         {
#                             "office_name": "Platinum Keller Williams Realty Alaska Group"
#                         }
#                     ],
#                     "spec_id": null,
#                     "type": "mls"
#                 },
#                 "tags": [
#                     "city_view",
#                     "community_outdoor_space",
#                     "community_security_features",
#                     "corner_lot",
#                     "hill_or_mountain_view",
#                     "lake_view",
#                     "ocean_view",
#                     "river_view",
#                     "spa_or_hot_tub",
#                     "garage_1_or_more",
#                     "garage_2_or_more",
#                     "two_or_more_stories",
#                     "vaulted_ceiling",
#                     "media_room",
#                     "ensuite",
#                     "private_courtyard",
#                     "trails"
#                 ],
#                 "permalink": "808-5th-St_Juneau_AK_99801_M76604-90777",
#                 "status": "sold",
#                 "list_date": "2023-08-21T21:01:22.000000Z",
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 1920,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-03",
#                     "sold_price": null,
#                     "baths_full": 3,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": 5875,
#                     "sqft": 3860,
#                     "baths": 3,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": 2,
#                     "stories": null,
#                     "beds": 5,
#                     "type": "single_family"
#                 },
#                 "branding": [
#                     {
#                         "name": "Southeast Alaska Real Estate",
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": 835000,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "7660490777",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": false
#                 },
#                 "community": null,
#                 "products": {
#                     "brand_name": "essentials"
#                 },
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958924095",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         },
#                         {
#                             "listing_id": "2941727948",
#                             "listing_key": null,
#                             "status": "off_market",
#                             "primary": null
#                         },
#                         {
#                             "listing_id": "2641864483",
#                             "listing_key": null,
#                             "status": "off_market",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": "2958924095",
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.403991,
#                             "lat": 58.304573
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "808 5th St"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=808%205th%20St%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=tV-uGGz9zKJiafcI3GDfgu9GV_I=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": "2023-12-07",
#                 "source": null,
#                 "tags": null,
#                 "permalink": "4446-Trafalgar-Ave_Juneau_AK_99801_M82741-21172",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 2002,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-07-21",
#                     "sold_price": null,
#                     "baths_full": 2,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": 7476,
#                     "sqft": 1375,
#                     "baths": 2,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": 1,
#                     "beds": 3,
#                     "type": "mobile"
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "8274121172",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": null,
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.553717,
#                             "lat": 58.396178
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "4446 Trafalgar Ave"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4446%20Trafalgar%20Ave%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=V24OM91aZHY5-heG-dKObuuYh4c=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             }
#         ]
#     }
# }
# <class 'dict'>

# %%
print(data['data'].keys())  # subkeys under 'data' in single file
# Out:
# dict_keys(['total', 'count', 'results'])

# %%
#single item results list
results = data['data']['results']
print(type(results))           
print(len(results))            # listings
print(results[0].keys())       # Keys in first listing
print(json.dumps(results[0], indent=2))  # first result
# Out:
# <class 'list'>
# 8
# dict_keys(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink', 'status', 'list_date', 'open_houses', 'description', 'branding', 'list_price', 'lead_attributes', 'property_id', 'photos', 'flags', 'community', 'products', 'virtual_tours', 'other_listings', 'listing_id', 'price_reduced_amount', 'location', 'matterport'])
# {
#   "primary_photo": {
#     "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#   },
#   "last_update_date": "2023-09-19T20:52:50Z",
#   "source": {
#     "plan_id": null,
#     "agents": [
#       {
#         "office_name": "EXP Realty LLC - Southeast Alaska"
#       },
#       {
#         "office_name": "Non-Member Office"
#       }
#     ],
#     "spec_id": null,
#     "type": "mls"
#   },
#   "tags": [
#     "carport",
#     "community_outdoor_space",
#     "cul_de_sac",
#     "family_room",
#     "hardwood_floors",
#     "hill_or_mountain_view",
#     "recreation_facilities",
#     "rv_or_boat_parking",
#     "basement",
#     "garage_1_or_more",
#     "two_or_more_stories",
#     "big_yard",
#     "high_ceiling",
#     "efficient",
#     "trails",
#     "shopping"
#   ],
#   "permalink": "9453-Herbert-Pl_Juneau_AK_99801_M90744-30767",
#   "status": "sold",
#   "list_date": "2023-06-29T21:16:25.000000Z",
#   "open_houses": null,
#   "description": {
#     "year_built": 1963,
#     "baths_3qtr": null,
#     "sold_date": "2023-09-18",
#     "sold_price": null,
#     "baths_full": 2,
#     "name": null,
#     "baths_half": null,
#     "lot_sqft": 10454,
#     "sqft": 1821,
#     "baths": 2,
#     "sub_type": null,
#     "baths_1qtr": null,
#     "garage": 1,
#     "stories": null,
#     "beds": 3,
#     "type": "single_family"
#   },
#   "branding": [
#     {
#       "name": "EXP Realty LLC - Southeast Alaska",
#       "photo": null,
#       "type": "Office"
#     }
#   ],
#   "list_price": 554950,
#   "lead_attributes": {
#     "show_contact_an_agent": true
#   },
#   "property_id": "9074430767",
#   "photos": [
#     {
#       "tags": [
#         {
#           "label": "house_view",
#           "probability": 0.9931892156601
#         },
#         {
#           "label": "road_view",
#           "probability": 0.84215885400772
#         },
#         {
#           "label": "house_view",
#           "probability": 0.93829786777496
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "living_room",
#           "probability": 0.99856203794479
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2021977128s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "dining_room",
#           "probability": 0.99998116493225
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2832281708s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "unknown",
#           "probability": 0.91968685388565
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2250208436s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "kitchen",
#           "probability": 0.99999892711639
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m4264543754s-w1024_h768.jpg"
#     }
#   ],
#   "flags": {
#     "is_new_construction": null,
#     "is_for_rent": null,
#     "is_subdivision": null,
#     "is_contingent": null,
#     "is_price_reduced": false,
#     "is_pending": null,
#     "is_foreclosure": null,
#     "is_plan": null,
#     "is_coming_soon": null,
#     "is_new_listing": false
#   },
#   "community": null,
#   "products": {
#     "brand_name": "basic_opt_in"
#   },
#   "virtual_tours": null,
#   "other_listings": {
#     "rdc": [
#       {
#         "listing_id": "2957241843",
#         "listing_key": null,
#         "status": "sold",
#         "primary": true
#       },
#       {
#         "listing_id": "2957022863",
#         "listing_key": null,
#         "status": "off_market",
#         "primary": null
#       }
#     ]
#   },
#   "listing_id": "2957241843",
#   "price_reduced_amount": 45000,
#   "location": {
#     "address": {
#       "postal_code": "99801",
#       "state": "Alaska",
#       "coordinate": {
#         "lon": -134.59372,
#         "lat": 58.36395
#       },
#       "city": "Juneau",
#       "state_code": "AK",
#       "line": "9453 Herbert Pl"
#     },
#     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9453%20Herbert%20Pl%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=OPv224SjFIJWgVKAXZKZXNYEdNQ=",
#     "county": {
#       "fips_code": null,
#       "name": "Juneau"
#     }
#   },
#   "matterport": false
# }

# %%
#diagnostic workflow 
with open('../data/AK_Juneau_0.json') as f:
    data = json.load(f)

print(data.keys())
print(data['data'].keys())
print(type(data['data']['results']))     # should be list
print(data['data']['results'][0].keys()) # first result fields
# Out:
# dict_keys(['status', 'data'])
# dict_keys(['total', 'count', 'results'])
# <class 'list'>
# dict_keys(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink', 'status', 'list_date', 'open_houses', 'description', 'branding', 'list_price', 'lead_attributes', 'property_id', 'photos', 'flags', 'community', 'products', 'virtual_tours', 'other_listings', 'listing_id', 'price_reduced_amount', 'location', 'matterport'])

# %%
#all json files, including one file, into dataframe; loop through each file, extract results, convert to DF

# Path to your JSON files
data_folder = '../data'

# List all JSON files
json_files = [f for f in os.listdir(data_folder) if f.endswith('.json')]

# Store all rows from all files
all_results = []

# Loop through each file
for filename in json_files:
    file_path = os.path.join(data_folder, filename)

    with open(file_path, 'r') as f:
        data = json.load(f)

    # Safely get the list of results
    results = data.get('data', {}).get('results', [])
    
    # Append each result to the master list
    all_results.extend(results)

# Convert the full list of results to a DataFrame
df = pd.DataFrame(all_results)

# Preview
print(df.shape)
print(df.head())
# Out:
# (8159, 23)
#                                        primary_photo      last_update_date  \
# 0  {'href': 'https://ap.rdcpix.com/07097d34c98a59...  2023-09-19T20:52:50Z
# 1                                               None                  None
# 2                                               None                  None
# 3                                               None                  None
# 4                                               None                  None
#
#                                               source  \
# 0  {'plan_id': None, 'agents': [{'office_name': '...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 tags  \
# 0  [carport, community_outdoor_space, cul_de_sac,...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                            permalink status  \
# 0       9453-Herbert-Pl_Juneau_AK_99801_M90744-30767   sold
# 1  8477-Thunder-Mountain-Rd_Juneau_AK_99801_M9424...   sold
# 2      4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516   sold
# 3  17850-Point-Stephens-Rd_Juneau_AK_99801_M98793...   sold
# 4  9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99...   sold
#
#                      list_date open_houses  \
# 0  2023-06-29T21:16:25.000000Z        None
# 1                         None        None
# 2                         None        None
# 3                         None        None
# 4                         None        None
#
#                                          description  \
# 0  {'year_built': 1963, 'baths_3qtr': None, 'sold...
# 1  {'year_built': None, 'baths_3qtr': None, 'sold...
# 2  {'year_built': None, 'baths_3qtr': None, 'sold...
# 3  {'year_built': None, 'baths_3qtr': None, 'sold...
# 4  {'year_built': None, 'baths_3qtr': None, 'sold...
#
#                                             branding  ...  \
# 0  [{'name': 'EXP Realty LLC - Southeast Alaska',...  ...
# 1  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# 2  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# 3  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# 4  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
#
#                                               photos  \
# 0  [{'tags': [{'label': 'house_view', 'probabilit...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                flags community  \
# 0  {'is_new_construction': None, 'is_for_rent': N...      None
# 1  {'is_new_construction': None, 'is_for_rent': N...      None
# 2  {'is_new_construction': None, 'is_for_rent': N...      None
# 3  {'is_new_construction': None, 'is_for_rent': N...      None
# 4  {'is_new_construction': None, 'is_for_rent': N...      None
#
#                          products virtual_tours  \
# 0  {'brand_name': 'basic_opt_in'}          None
# 1                            None          None
# 2                            None          None
# 3                            None          None
# 4                            None          None
#
#                                       other_listings  listing_id  \
# 0  {'rdc': [{'listing_id': '2957241843', 'listing...  2957241843
# 1  {'rdc': [{'listing_id': '2958935271', 'listing...        None
# 2  {'rdc': [{'listing_id': '2958935192', 'listing...        None
# 3  {'rdc': [{'listing_id': '2958925235', 'listing...        None
# 4  {'rdc': [{'listing_id': '2958924367', 'listing...        None
#
#   price_reduced_amount                                           location  \
# 0              45000.0  {'address': {'postal_code': '99801', 'state': ...
# 1                  NaN  {'address': {'postal_code': '99801', 'state': ...
# 2                  NaN  {'address': {'postal_code': '99801', 'state': ...
# 3                  NaN  {'address': {'postal_code': '99801', 'state': ...
# 4                  NaN  {'address': {'postal_code': '99801', 'state': ...
#
#   matterport
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink',
#        'status', 'list_date', 'open_houses', 'description', 'branding',
#        'list_price', 'lead_attributes', 'property_id', 'photos', 'flags',
#        'community', 'products', 'virtual_tours', 'other_listings',
#        'listing_id', 'price_reduced_amount', 'location', 'matterport'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning and Wrangling

# %% [markdown]
# At this point, ensure that you have all sales in a dataframe.
# - Take a quick look at your data (i.e. `.info()`, `.describe()`) - what do you see?
# - Is each cell one value, or do some cells have lists?
# - What are the data types of each column?
# - Some sales may not actually include the sale price (target).  These rows should be dropped.
# - There are a lot of NA/None values.  Should these be dropped or replaced with something?
#     - You can drop rows or use various methods to fills NA's - use your best judgement for each column
#     - i.e. for some columns (like Garage), NA probably just means no Garage, so 0
# - Drop columns that aren't needed
#     - Don't keep the list price because it will be too close to the sale price. Assume we want to predict the price of houses not yet listed

# %%
df = pd.DataFrame(all_results)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8159 entries, 0 to 8158
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   primary_photo         7403 non-null   object
#  1   last_update_date      8125 non-null   object
#  2   source                7752 non-null   object
#  3   tags                  7638 non-null   object
#  4   permalink             8159 non-null   object
#  5   status                8159 non-null   object
#  6   list_date             7752 non-null   object
#  7   open_houses           0 non-null      object
#  8   description           8159 non-null   object
#  9   branding              8159 non-null   object
#  10  list_price            7721 non-null   float64
#  11  lead_attributes       8159 non-null   object
#  12  property_id           8159 non-null   object
#  13  photos                7403 non-null   object
#  14  flags                 8159 non-null   object
#  15  community             5 non-null      object
#  16  products              7673 non-null   object
#  17  virtual_tours         1351 non-null   object
#  18  other_listings        7856 non-null   object
#  19  listing_id            7752 non-null   object
#  20  price_reduced_amount  2484 non-null   float64
#  21  location              8159 non-null   object
#  22  matterport            8159 non-null   bool
# dtypes: bool(1), float64(2), object(20)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (8159, 23)

# %%
df.describe(include='all')
# Out:
#                                             primary_photo last_update_date  \
# count                                                7403             8125
# unique                                               1627             1716
# top     {'href': 'https://ap.rdcpix.com/ad5d27c0b1692b...       2023-10-20
# freq                                                    5               95
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                                                    source       tags  \
# count                                                7752       7638
# unique                                                393       1628
# top     {'plan_id': None, 'agents': [{'office_name': N...  [big_lot]
# freq                                                 5127         62
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#                                                 permalink status  \
# count                                                8159   8159
# unique                                               1795      1
# top     1410-Ridgewood-Dr-Ab_Jefferson-City_MO_65109_M...   sold
# freq                                                    5   8159
# mean                                                  NaN    NaN
# std                                                   NaN    NaN
# min                                                   NaN    NaN
# 25%                                                   NaN    NaN
# 50%                                                   NaN    NaN
# 75%                                                   NaN    NaN
# max                                                   NaN    NaN
#
#                           list_date open_houses  \
# count                          7752           0
# unique                         1636           0
# top     2024-01-05T17:38:27.000000Z         NaN
# freq                             80         NaN
# mean                            NaN         NaN
# std                             NaN         NaN
# min                             NaN         NaN
# 25%                             NaN         NaN
# 50%                             NaN         NaN
# 75%                             NaN         NaN
# max                             NaN         NaN
#
#                                               description  \
# count                                                8159
# unique                                               1791
# top     {'year_built': None, 'baths_3qtr': None, 'sold...
# freq                                                   10
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  branding  ...  \
# count                                                8159  ...
# unique                                                996  ...
# top     [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# freq                                                  434  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#                                                    photos  \
# count                                                7403
# unique                                               1627
# top     [{'tags': [{'label': 'house_view', 'probabilit...
# freq                                                    5
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     flags  \
# count                                                8159
# unique                                                  6
# top     {'is_new_construction': None, 'is_for_rent': N...
# freq                                                 5231
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 community  \
# count                                                   5
# unique                                                  1
# top     {'advertisers': [{'office': {'hours': 'Monday ...
# freq                                                    5
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                             products  \
# count                           7673
# unique                             4
# top     {'brand_name': 'essentials'}
# freq                            4900
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
#                                             virtual_tours  \
# count                                                1351
# unique                                                290
# top     [{'type': None, 'href': 'https://cambiomhc.com...
# freq                                                   20
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            other_listings  listing_id  \
# count                                                7856        7752
# unique                                               1726        1704
# top     {'rdc': [{'listing_id': '2960264046', 'listing...  2962644673
# freq                                                    5           5
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#        price_reduced_amount  \
# count          2.484000e+03
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean           2.442704e+04
# std            7.162396e+04
# min            1.000000e+02
# 25%            6.000000e+03
# 50%            1.010000e+04
# 75%            2.000000e+04
# max            2.015999e+06
#
#                                                  location matterport
# count                                                8159       8159
# unique                                               1794          2
# top     {'address': {'postal_code': '50036', 'state': ...      False
# freq                                                    7       7830
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
# [11 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink',
#        'status', 'list_date', 'open_houses', 'description', 'branding',
#        'list_price', 'lead_attributes', 'property_id', 'photos', 'flags',
#        'community', 'products', 'virtual_tours', 'other_listings',
#        'listing_id', 'price_reduced_amount', 'location', 'matterport'],
#       dtype='object')

# %%
# cell value; false = cell does not contain list, true = cell contains list
df = pd.DataFrame(all_results)

# check if each cell contains a list
is_list = df.map(lambda x: isinstance(x, list))

# result
print(is_list)
# Out:
#       primary_photo  last_update_date  source   tags  permalink  status  \
# 0             False             False   False   True      False   False
# 1             False             False   False  False      False   False
# 2             False             False   False  False      False   False
# 3             False             False   False  False      False   False
# 4             False             False   False  False      False   False
# ...             ...               ...     ...    ...        ...     ...
# 8154          False             False   False   True      False   False
# 8155          False             False   False   True      False   False
# 8156          False             False   False   True      False   False
# 8157          False             False   False   True      False   False
# 8158          False             False   False   True      False   False
#
#       list_date  open_houses  description  branding  ...  photos  flags  \
# 0         False        False        False      True  ...    True  False
# 1         False        False        False      True  ...   False  False
# 2         False        False        False      True  ...   False  False
# 3         False        False        False      True  ...   False  False
# 4         False        False        False      True  ...   False  False
# ...         ...          ...          ...       ...  ...     ...    ...
# 8154      False        False        False      True  ...    True  False
# 8155      False        False        False      True  ...    True  False
# 8156      False        False        False      True  ...    True  False
# 8157      False        False        False      True  ...    True  False
# 8158      False        False        False      True  ...    True  False
#
#       community  products  virtual_tours  other_listings  listing_id  \
# 0         False     False          False           False       False
# 1         False     False          False           False       False
# 2         False     False          False           False       False
# 3         False     False          False           False       False
# 4         False     False          False           False       False
# ...         ...       ...            ...             ...         ...
# 8154      False     False          False           False       False
# 8155      False     False          False           False       False
# 8156      False     False          False           False       False
# 8157      False     False          False           False       False
# 8158      False     False          False           False       False
#
#       price_reduced_amount  location  matterport
# 0                    False     False       False
# 1                    False     False       False
# 2                    False     False       False
# 3                    False     False       False
# 4                    False     False       False
# ...                    ...       ...         ...
# 8154                 False     False       False
# 8155                 False     False       False
# 8156                 False     False       False
# 8157                 False     False       False
# 8158                 False     False       False
#
# [8159 rows x 23 columns]

# %%
#sold price print df head only - keep for reference re drop list price 
for index, row in df.head().iterrows():
    print(f"Row {index} - Sold Price: {row['description'].get('sold_price', 'Not Available')}")
# Out:
# Row 0 - Sold Price: None
# Row 1 - Sold Price: None
# Row 2 - Sold Price: None
# Row 3 - Sold Price: None
# Row 4 - Sold Price: None

# %%
#print df head with sales with or without sales price  
print(df.head())
# Out:
#                                        primary_photo      last_update_date  \
# 0  {'href': 'https://ap.rdcpix.com/07097d34c98a59...  2023-09-19T20:52:50Z
# 1                                               None                  None
# 2                                               None                  None
# 3                                               None                  None
# 4                                               None                  None
#
#                                               source  \
# 0  {'plan_id': None, 'agents': [{'office_name': '...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 tags  \
# 0  [carport, community_outdoor_space, cul_de_sac,...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                            permalink status  \
# 0       9453-Herbert-Pl_Juneau_AK_99801_M90744-30767   sold
# 1  8477-Thunder-Mountain-Rd_Juneau_AK_99801_M9424...   sold
# 2      4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516   sold
# 3  17850-Point-Stephens-Rd_Juneau_AK_99801_M98793...   sold
# 4  9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99...   sold
#
#                      list_date open_houses  \
# 0  2023-06-29T21:16:25.000000Z        None
# 1                         None        None
# 2                         None        None
# 3                         None        None
# 4                         None        None
#
#                                          description  \
# 0  {'year_built': 1963, 'baths_3qtr': None, 'sold...
# 1  {'year_built': None, 'baths_3qtr': None, 'sold...
# 2  {'year_built': None, 'baths_3qtr': None, 'sold...
# 3  {'year_built': None, 'baths_3qtr': None, 'sold...
# 4  {'year_built': None, 'baths_3qtr': None, 'sold...
#
#                                             branding  ...  \
# 0  [{'name': 'EXP Realty LLC - Southeast Alaska',...  ...
# 1  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# 2  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# 3  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# 4  [{'name': None, 'photo': None, 'type': 'Office'}]  ...
#
#                                               photos  \
# 0  [{'tags': [{'label': 'house_view', 'probabilit...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                flags community  \
# 0  {'is_new_construction': None, 'is_for_rent': N...      None
# 1  {'is_new_construction': None, 'is_for_rent': N...      None
# 2  {'is_new_construction': None, 'is_for_rent': N...      None
# 3  {'is_new_construction': None, 'is_for_rent': N...      None
# 4  {'is_new_construction': None, 'is_for_rent': N...      None
#
#                          products virtual_tours  \
# 0  {'brand_name': 'basic_opt_in'}          None
# 1                            None          None
# 2                            None          None
# 3                            None          None
# 4                            None          None
#
#                                       other_listings  listing_id  \
# 0  {'rdc': [{'listing_id': '2957241843', 'listing...  2957241843
# 1  {'rdc': [{'listing_id': '2958935271', 'listing...        None
# 2  {'rdc': [{'listing_id': '2958935192', 'listing...        None
# 3  {'rdc': [{'listing_id': '2958925235', 'listing...        None
# 4  {'rdc': [{'listing_id': '2958924367', 'listing...        None
#
#   price_reduced_amount                                           location  \
# 0              45000.0  {'address': {'postal_code': '99801', 'state': ...
# 1                  NaN  {'address': {'postal_code': '99801', 'state': ...
# 2                  NaN  {'address': {'postal_code': '99801', 'state': ...
# 3                  NaN  {'address': {'postal_code': '99801', 'state': ...
# 4                  NaN  {'address': {'postal_code': '99801', 'state': ...
#
#   matterport
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 23 columns]

# %%
#drop sales without sales price; print findings
def has_valid_sold_price(d):
    sold_price = d.get('sold_price', None)
    return sold_price not in [None, '', 0, '0']

#filter rows with invalid sold_price
filtered_df = df[df['description'].apply(has_valid_sold_price)]

#print df head findings
for index, row in filtered_df.head().iterrows():
    print(f"Row {index} - Sold Price: {row['description']['sold_price']}")
# Out:
# Row 30 - Sold Price: 129900
# Row 31 - Sold Price: 88500
# Row 32 - Sold Price: 145000
# Row 33 - Sold Price: 65000
# Row 34 - Sold Price: 169000

# %%
#print filtered df removing sales without sales price (includes removal empty or zero sales prices)
print(filtered_df.head())
# Out:
#                                         primary_photo      last_update_date  \
# 30                                               None  2021-04-13T17:14:34Z
# 31  {'href': 'https://ap.rdcpix.com/a5fe1391acf35d...  2024-01-16T16:07:56Z
# 32                                               None  2021-04-13T17:14:32Z
# 33  {'href': 'https://ap.rdcpix.com/c41ec0e28b89fa...  2024-01-16T16:05:10Z
# 34  {'href': 'https://ap.rdcpix.com/1e4bac70e24f78...  2024-01-12T20:22:58Z
#
#                                                source  \
# 30  {'plan_id': None, 'agents': [{'office_name': '...
# 31  {'plan_id': None, 'agents': [{'office_name': '...
# 32  {'plan_id': None, 'agents': [{'office_name': '...
# 33  {'plan_id': None, 'agents': [{'office_name': '...
# 34  {'plan_id': None, 'agents': [{'office_name': '...
#
#                                                  tags  \
# 30  [central_air, central_heat, community_outdoor_...
# 31  [city_view, hardwood_floors, two_or_more_stori...
# 32  [carport, central_air, central_heat, dishwashe...
# 33  [carport, central_air, city_view, community_ou...
# 34  [city_view, single_story, big_yard, fenced_yar...
#
#                                             permalink status  \
# 30  501-Moorfield-Ln_Montgomery_AL_36117_M88465-41030   sold
# 31   2326-Winona-Ave_Montgomery_AL_36107_M77279-81021   sold
# 32  115-Lookout-Ridge-Rd_Montgomery_AL_36109_M7320...   sold
# 33   611-Glenmore-Rd_Montgomery_AL_36107_M72316-04965   sold
# 34  1819-E-Trinity-Blvd_Montgomery_AL_36106_M77006...   sold
#
#                       list_date open_houses  \
# 30  2023-12-19T18:08:22.000000Z        None
# 31  2023-11-10T14:20:36.000000Z        None
# 32  2023-12-19T18:08:22.000000Z        None
# 33  2023-07-05T16:47:40.000000Z        None
# 34  2023-10-29T17:55:28.000000Z        None
#
#                                           description  \
# 30  {'year_built': 1998, 'baths_3qtr': None, 'sold...
# 31  {'year_built': 1945, 'baths_3qtr': None, 'sold...
# 32  {'year_built': 1969, 'baths_3qtr': None, 'sold...
# 33  {'year_built': 1955, 'baths_3qtr': None, 'sold...
# 34  {'year_built': 1984, 'baths_3qtr': None, 'sold...
#
#                                              branding  ...  \
# 30  [{'name': 'Forrest Meadows Homes & Land', 'pho...  ...
# 31  [{'name': 'Wallace & Moody Realty', 'photo': N...  ...
# 32  [{'name': 'FlatFee.com', 'photo': None, 'type'...  ...
# 33  [{'name': 'Wallace & Moody Realty', 'photo': N...  ...
# 34  [{'name': 'List With Freedom, Inc.', 'photo': ...  ...
#
#                                                photos  \
# 30                                               None
# 31  [{'tags': [{'label': 'house_view', 'probabilit...
# 32                                               None
# 33  [{'tags': [{'label': 'house_view', 'probabilit...
# 34  [{'tags': [{'label': 'house_view', 'probabilit...
#
#                                                 flags community  \
# 30  {'is_new_construction': None, 'is_for_rent': N...      None
# 31  {'is_new_construction': None, 'is_for_rent': N...      None
# 32  {'is_new_construction': None, 'is_for_rent': N...      None
# 33  {'is_new_construction': None, 'is_for_rent': N...      None
# 34  {'is_new_construction': None, 'is_for_rent': N...      None
#
#                           products virtual_tours  \
# 30    {'brand_name': 'essentials'}          None
# 31    {'brand_name': 'essentials'}          None
# 32    {'brand_name': 'essentials'}          None
# 33    {'brand_name': 'essentials'}          None
# 34  {'brand_name': 'basic_opt_in'}          None
#
#                                        other_listings  listing_id  \
# 30  {'rdc': [{'listing_id': '622475855', 'listing_...   622475855
# 31  {'rdc': [{'listing_id': '2961522977', 'listing...  2961522977
# 32  {'rdc': [{'listing_id': '619793175', 'listing_...   619793175
# 33  {'rdc': [{'listing_id': '2957379146', 'listing...  2957379146
# 34  {'rdc': [{'listing_id': '2960975584', 'listing...  2960975584
#
#    price_reduced_amount                                           location  \
# 30                  NaN  {'address': {'postal_code': '36117', 'state': ...
# 31               3000.0  {'address': {'postal_code': '36107', 'state': ...
# 32                  NaN  {'address': {'postal_code': '36109', 'state': ...
# 33               9000.0  {'address': {'postal_code': '36107', 'state': ...
# 34               5000.0  {'address': {'postal_code': '36106', 'state': ...
#
#    matterport
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
#
# [5 rows x 23 columns]

# %%
#evaluate NA/None values to be dropped/replaced for each column
df = pd.DataFrame(all_results)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8159 entries, 0 to 8158
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   primary_photo         7403 non-null   object
#  1   last_update_date      8125 non-null   object
#  2   source                7752 non-null   object
#  3   tags                  7638 non-null   object
#  4   permalink             8159 non-null   object
#  5   status                8159 non-null   object
#  6   list_date             7752 non-null   object
#  7   open_houses           0 non-null      object
#  8   description           8159 non-null   object
#  9   branding              8159 non-null   object
#  10  list_price            7721 non-null   float64
#  11  lead_attributes       8159 non-null   object
#  12  property_id           8159 non-null   object
#  13  photos                7403 non-null   object
#  14  flags                 8159 non-null   object
#  15  community             5 non-null      object
#  16  products              7673 non-null   object
#  17  virtual_tours         1351 non-null   object
#  18  other_listings        7856 non-null   object
#  19  listing_id            7752 non-null   object
#  20  price_reduced_amount  2484 non-null   float64
#  21  location              8159 non-null   object
#  22  matterport            8159 non-null   bool
# dtypes: bool(1), float64(2), object(20)
# memory usage: 1.4+ MB

# %%
# columns containing NA/None values
columns_with_na = df.columns[df.isna().any()].tolist()

# Identify columns with missing values
na_counts = df.isna().sum()
columns_with_na = na_counts[na_counts > 0]

# display columns with missing values
print("\nColumns with NA/None values:")
print(columns_with_na)
# Out:
# Columns with NA/None values:
# primary_photo            756
# last_update_date          34
# source                   407
# tags                     521
# list_date                407
# open_houses             8159
# list_price               438
# photos                   756
# community               8154
# products                 486
# virtual_tours           6808
# other_listings           303
# listing_id               407
# price_reduced_amount    5675
# dtype: int64

# %%
# columns identified to drop
columns_to_drop = ['primary_photo', 'last_update_date','list_price', 'source', 'open_houses', 'products', 'other_listings']

# drop columns from df
df.drop(columns=columns_to_drop, inplace=True)

# confirm columns dropped
print("Remaining columns:")
print(df.columns)
# Out:
# Remaining columns:
# Index(['tags', 'permalink', 'status', 'list_date', 'description', 'branding',
#        'lead_attributes', 'property_id', 'photos', 'flags', 'community',
#        'virtual_tours', 'listing_id', 'price_reduced_amount', 'location',
#        'matterport'],
#       dtype='object')

# %%
# identified columns to replace with alternative value 
# replace NA/None value in virtual tours with '0' in specific columns
df['virtual_tours'] = df['virtual_tours'].fillna(0)
df['price_reduced_amount'] = df['price_reduced_amount'].fillna(0)
df['tags'] = df['tags'].fillna(0)

# print changes to confirm
print(df.head())
# Out:
#                                                 tags  \
# 0  [carport, community_outdoor_space, cul_de_sac,...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                            permalink status  \
# 0       9453-Herbert-Pl_Juneau_AK_99801_M90744-30767   sold
# 1  8477-Thunder-Mountain-Rd_Juneau_AK_99801_M9424...   sold
# 2      4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516   sold
# 3  17850-Point-Stephens-Rd_Juneau_AK_99801_M98793...   sold
# 4  9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99...   sold
#
#                      list_date  \
# 0  2023-06-29T21:16:25.000000Z
# 1                         None
# 2                         None
# 3                         None
# 4                         None
#
#                                          description  \
# 0  {'year_built': 1963, 'baths_3qtr': None, 'sold...
# 1  {'year_built': None, 'baths_3qtr': None, 'sold...
# 2  {'year_built': None, 'baths_3qtr': None, 'sold...
# 3  {'year_built': None, 'baths_3qtr': None, 'sold...
# 4  {'year_built': None, 'baths_3qtr': None, 'sold...
#
#                                             branding  \
# 0  [{'name': 'EXP Realty LLC - Southeast Alaska',...
# 1  [{'name': None, 'photo': None, 'type': 'Office'}]
# 2  [{'name': None, 'photo': None, 'type': 'Office'}]
# 3  [{'name': None, 'photo': None, 'type': 'Office'}]
# 4  [{'name': None, 'photo': None, 'type': 'Office'}]
#
#                    lead_attributes property_id  \
# 0  {'show_contact_an_agent': True}  9074430767
# 1  {'show_contact_an_agent': True}  9424983842
# 2  {'show_contact_an_agent': True}  9479068516
# 3  {'show_contact_an_agent': True}  9879331943
# 4  {'show_contact_an_agent': True}  9521639574
#
#                                               photos  \
# 0  [{'tags': [{'label': 'house_view', 'probabilit...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                flags community virtual_tours  \
# 0  {'is_new_construction': None, 'is_for_rent': N...      None             0
# 1  {'is_new_construction': None, 'is_for_rent': N...      None             0
# 2  {'is_new_construction': None, 'is_for_rent': N...      None             0
# 3  {'is_new_construction': None, 'is_for_rent': N...      None             0
# 4  {'is_new_construction': None, 'is_for_rent': N...      None             0
#
#    listing_id  price_reduced_amount  \
# 0  2957241843               45000.0
# 1        None                   0.0
# 2        None                   0.0
# 3        None                   0.0
# 4        None                   0.0
#
#                                             location  matterport
# 0  {'address': {'postal_code': '99801', 'state': ...       False
# 1  {'address': {'postal_code': '99801', 'state': ...       False
# 2  {'address': {'postal_code': '99801', 'state': ...       False
# 3  {'address': {'postal_code': '99801', 'state': ...       False
# 4  {'address': {'postal_code': '99801', 'state': ...       False

# %% [markdown]
# ### Dealing with Tags

# %% [markdown]
# Consider the fact that with tags, there are a lot of categorical variables.
# - How many columns would we have if we OHE tags, city and state?
# - Perhaps we can get rid of tags that have a low frequency.

# %%
# Extract city and state from location
df['city'] = df['location'].apply(lambda x: x.get('address', {}).get('city') if isinstance(x, dict) else None)
df['state'] = df['location'].apply(lambda x: x.get('address', {}).get('state') if isinstance(x, dict) else None)

# Clean tags column to ensure lists
df['tags'] = df['tags'].apply(lambda x: x if isinstance(x, list) else [])

# Count all tags
all_tags = [tag for tags in df['tags'] for tag in tags]
tag_counts = Counter(all_tags)

# Unique counts for city and state
unique_cities = df['city'].nunique()
unique_states = df['state'].nunique()

# Filter tags with more than 10 occurrences
frequent_tags = [tag for tag, count in tag_counts.items() if count > 10]

print(f"Unique cities: {unique_cities}")
print(f"Unique states: {unique_states}")
print(f"Total unique tags: {len(tag_counts)}")
print(f"Frequent tags (>10 occurrences): {len(frequent_tags)}")

# Estimate total OHE columns: city + state + filtered tags
total_ohe_columns = unique_cities + unique_states + len(frequent_tags)
print(f"Estimated total OHE columns: {total_ohe_columns}")
# Out:
# Unique cities: 101
# Unique states: 45
# Total unique tags: 155
# Frequent tags (>10 occurrences): 142
# Estimated total OHE columns: 288

# %%
# Define frequency threshold for city/state
city_threshold = 5
state_threshold = 5

# Count city and state occurrences
city_counts = df['city'].value_counts()
state_counts = df['state'].value_counts()

# Replace rare cities/states with 'Other'
df['city'] = df['city'].apply(lambda x: x if city_counts.get(x, 0) > city_threshold else 'Other')
df['state'] = df['state'].apply(lambda x: x if state_counts.get(x, 0) > state_threshold else 'Other')

# After replacement, recount unique cities/states
unique_cities = df['city'].nunique()
unique_states = df['state'].nunique()

print(f"Unique cities after merging rare: {unique_cities}")
print(f"Unique states after merging rare: {unique_states}")
# Out:
# Unique cities after merging rare: 64
# Unique states after merging rare: 45

# %%
import matplotlib.pyplot as plt

# Get tag counts as a list
tag_count_values = list(tag_counts.values())

plt.figure(figsize=(10,6))
plt.hist(tag_count_values, bins=30, edgecolor='black')
plt.title('Tag Frequency Distribution')
plt.xlabel('Number of Occurrences')
plt.ylabel('Number of Tags')
plt.grid(axis='y')
plt.show()

# %%
freq_threshold = 20
frequent_tags = [tag for tag, count in tag_counts.items() if count > freq_threshold]
print(f"Frequent tags (>20 occurrences): {len(frequent_tags)}")

total_ohe_columns = unique_cities + unique_states + len(frequent_tags)
print(f"Estimated total OHE columns after merging rare cities/states and threshold 20 tags: {total_ohe_columns}")
# Out:
# Frequent tags (>20 occurrences): 134
# Estimated total OHE columns after merging rare cities/states and threshold 20 tags: 243

# %% [markdown]
# ### Dealing with Cities
#
#
# - Sales will vary drastically between cities and states.  Is there a way to keep information about which city it is without OHE?
# - Could we label encode or ordinal encode?  Yes, but this may have undesirable effects, giving nominal data ordinal values.
# - What we can do is use our training data to encode the mean sale price by city as a feature (a.k.a. Target Encoding)
#     - We can do this as long as we ONLY use the training data - we're using the available data to give us a 'starting guess' of the price for each city, without needing to encode city explicitly
# - If you replace cities or states with numerical values (like the mean price), make sure that the data is split so that we don't leak data into the training selection. This is a great time to train test split. Compute on the training data, and join these values to the test data
# - Note that you *may* have cities in the test set that are not in the training set. You don't want these to be NA, so maybe you can fill them with the overall mean

# %%
print(df.columns)
print(df['description'].iloc[0])
print(type(df['description'].iloc[0]))
# extract sold_price from 'description' column
df['Sold Price'] = df['description'].apply(lambda x: x.get('sold_price', None))
# Out:
# Index(['tags', 'permalink', 'status', 'list_date', 'description', 'branding',
#        'lead_attributes', 'property_id', 'photos', 'flags', 'community',
#        'virtual_tours', 'listing_id', 'price_reduced_amount', 'location',
#        'matterport', 'city', 'state'],
#       dtype='object')
# {'year_built': 1963, 'baths_3qtr': None, 'sold_date': '2023-09-18', 'sold_price': None, 'baths_full': 2, 'name': None, 'baths_half': None, 'lot_sqft': 10454, 'sqft': 1821, 'baths': 2, 'sub_type': None, 'baths_1qtr': None, 'garage': 1, 'stories': None, 'beds': 3, 'type': 'single_family'}
# <class 'dict'>

# %%
df['city'] = df['location'].apply(lambda x: x.get('address', {}).get('city') if isinstance(x, dict) else None)

# %%
from sklearn.model_selection import train_test_split

# Split data
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Compute mean price by city using training data
city_means = train_df.groupby('city')['Sold Price'].mean()

# Global mean to fill unknown cities
global_mean = train_df['Sold Price'].mean()

# Create the new encoded columns as separate Series
train_city_encoded = train_df['city'].map(city_means)
test_city_encoded = test_df['city'].map(city_means).fillna(global_mean)

# Combine using concat all at once
train_df = pd.concat([train_df, train_city_encoded.rename('city_encoded')], axis=1)
test_df = pd.concat([test_df, test_city_encoded.rename('city_encoded')], axis=1)

# Defragment by making a copy 
train_df = train_df.copy()
test_df = test_df.copy()

# %% [markdown]
# ## Extra Data - STRETCH
#
# > This doesn't need to be part of your Minimum Viable Product (MVP). We recommend you write a functional, basic pipeline first, then circle back and join new data if you have time
#
# > If you do this, try to write your downstream steps in a way it will still work on a dataframe with different features!
#
# - You're not limited to just using the data provided to you. Think/ do some research about other features that might be useful to predict housing prices.
# - Can you import and join this data? Make sure you do any necessary preprocessing and make sure it is joined correctly.
# - Example suggestion: could mortgage interest rates in the year of the listing affect the price?

# %%
# import, join and preprocess new data here

# %% [markdown]
# ## EDA/ Visualization
#
# Remember all of the EDA that you've been learning about?  Now is a perfect time for it!
# - Look at distributions of numerical variables to see the shape of the data and detect outliers.
#     - Consider transforming very skewed variables
# - Scatterplots of a numerical variable and the target go a long way to show correlations.
# - A heatmap will help detect highly correlated features, and we don't want these.
#     - You may have too many features to do this, in which case you can simply compute the most correlated feature-pairs and list them
# - Is there any overlap in any of the features? (redundant information, like number of this or that room...)

# %%
import seaborn as sns
df['sold_price'] = df['description'].apply(lambda x: x.get('sold_price') if isinstance(x, dict) else None)

# %%
# OHE tags
tags_ohe = df['tags'].str.get_dummies(sep=',')

# combine with sold price
tags_with_sold_price = pd.concat([tags_ohe, df['sold_price']], axis=1)

# drop rows with missing sold_price (if any)
tags_with_sold_price = tags_with_sold_price.dropna(subset=['sold_price'])

# compute correlation
tag_price_corr = tags_with_sold_price.corr()['sold_price'].drop('sold_price')

# %%
# Filter tags with absolute correlation > 0.1
threshold = 0.1
strong_corr_tags = tag_price_corr[tag_price_corr.abs() > threshold]

# Convert to DataFrame and sort
strong_corr_df = strong_corr_tags.to_frame(name='correlation').sort_values(by='correlation', ascending=False)

# Plot heatmap
plt.figure(figsize=(6, len(strong_corr_df) * 0.5))
sns.heatmap(strong_corr_df, annot=True, cmap='coolwarm', center=0)
plt.title(f'Tags with abs(correlation) > {threshold} to Sold Price')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Numeric columns to check
numeric_cols = ['price', 'beds', 'baths', 'sqft', 'year_built', 'garage', 'stories']

plt.figure(figsize=(16, 12))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(3, 3, i)
    sns.histplot(df[col].dropna(), kde=True, color='skyblue', bins=30)
    plt.title(f'Distribution & Skewness of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       9 for i, col in enumerate(numeric_cols, 1):
#      10     plt.subplot(3, 3, i)
# ---> 11     sns.histplot(df[col].dropna(), kde=True, color='skyblue', bins=30)
#      12     plt.title(f'Distribution & Skewness of {col}')
#      13     plt.xlabel(col)
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = df.select_dtypes(include='number').columns

for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
df[numerical_cols].skew().sort_values(ascending=False)

df['log_price'] = np.log1p(df['sold_price'])

# %%
for col in numerical_cols:
    if col != 'sold_price':
        plt.figure(figsize=(6, 4))
        sns.scatterplot(data=df, x=col, y='sold_price')
        plt.title(f'{col} vs Sold Price')
        plt.show()

# %%
sns.histplot(df['sold_price'], kde=True)
# Out:
# <Axes: xlabel='sold_price', ylabel='Count'>

# %% [markdown]
# ## Scaling and Finishing Up

# %% [markdown]
# Now is a great time to scale the data and save it once it's preprocessed.
# - You can save it in your data folder, but you may want to make a new `processed/` subfolder to keep it organized

# %%
from sklearn.preprocessing import StandardScaler

# Select only numeric columns for scaling
numerical_cols = df.select_dtypes(include='number').columns

# Initialize scaler and fit-transform
scaler = StandardScaler()
df_scaled = df.copy()
df_scaled[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
# Create a processed folder if it doesn't exist
os.makedirs('data/processed', exist_ok=True)

# Save the processed DataFrame
df_scaled.to_csv('data/processed/df_scaled.csv', index=False)
