# %% [markdown]
# # EDA

# %% [markdown]
# - The os module has a perfect method to list files in a directory.
# - Pandas json normalize could work here but is not necessary to convert the JSON data to a dataframe.
# - You may need a nested for-loop to access each sale!
# - We've put a lot of time into creating the structure of this repository, and it's a good example for future projects.  In the file functions_variables.py, there is an example function that you can import and use.  If you have any variables, functions or classes that you want to make, they can be put in the functions_variables.py file and imported into a notebook.  Note that only .py files can be imported into a notebook. If you want to import everything from a .py file, you can use the following:
# ```python
# from functions_variables import *
# ```
# If you just import functions_variables, then each object from the file will need to be prepended with "functions_variables"\
# Using this .py file will keep your notebooks very organized and make it easier to reuse code between notebooks.

# %%
import pandas as pd
import numpy as np
import os
import json
from pprint import pprint
from functions_variables import encode_tags
from collections import Counter

# %% [markdown]
# ## Data Importing

# %%
# load one file first to see what type of data and attributes
with open('../data/AK_Juneau_0.json', 'r') as f:
    data = json.load(f)

# %%
print(type(data))         # one file attribute
print(data.keys())        # top-level keys
# Out:
# <class 'dict'>
# dict_keys(['status', 'data'])

# %%
#load json object
with open('../data/AK_Juneau_0.json') as f:
    nested_json = json.load(f)
print(nested_json)

#attribute of data
print(type(nested_json))
# Out:
# {'status': 200, 'data': {'total': 8, 'count': 8, 'results': [{'primary_photo': {'href': 'https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg'}, 'last_update_date': '2023-09-19T20:52:50Z', 'source': {'plan_id': None, 'agents': [{'office_name': 'EXP Realty LLC - Southeast Alaska'}, {'office_name': 'Non-Member Office'}], 'spec_id': None, 'type': 'mls'}, 'tags': ['carport', 'community_outdoor_space', 'cul_de_sac', 'family_room', 'hardwood_floors', 'hill_or_mountain_view', 'recreation_facilities', 'rv_or_boat_parking', 'basement', 'garage_1_or_more', 'two_or_more_stories', 'big_yard', 'high_ceiling', 'efficient', 'trails', 'shopping'], 'permalink': '9453-Herbert-Pl_Juneau_AK_99801_M90744-30767', 'status': 'sold', 'list_date': '2023-06-29T21:16:25.000000Z', 'open_houses': None, 'description': {'year_built': 1963, 'baths_3qtr': None, 'sold_date': '2023-09-18', 'sold_price': None, 'baths_full': 2, 'name': None, 'baths_half': None, 'lot_sqft': 10454, 'sqft': 1821, 'baths': 2, 'sub_type': None, 'baths_1qtr': None, 'garage': 1, 'stories': None, 'beds': 3, 'type': 'single_family'}, 'branding': [{'name': 'EXP Realty LLC - Southeast Alaska', 'photo': None, 'type': 'Office'}], 'list_price': 554950, 'lead_attributes': {'show_contact_an_agent': True}, 'property_id': '9074430767', 'photos': [{'tags': [{'label': 'house_view', 'probability': 0.9931892156601}, {'label': 'road_view', 'probability': 0.84215885400772}, {'label': 'house_view', 'probability': 0.93829786777496}], 'href': 'https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg'}, {'tags': [{'label': 'living_room', 'probability': 0.99856203794479}], 'href': 'https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2021977128s-w1024_h768.jpg'}, {'tags': [{'label': 'dining_room', 'probability': 0.99998116493225}], 'href': 'https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2832281708s-w1024_h768.jpg'}, {'tags': [{'label': 'unknown', 'probability': 0.91968685388565}], 'href': 'https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2250208436s-w1024_h768.jpg'}, {'tags': [{'label': 'kitchen', 'probability': 0.99999892711639}], 'href': 'https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m4264543754s-w1024_h768.jpg'}], 'flags': {'is_new_construction': None, 'is_for_rent': None, 'is_subdivision': None, 'is_contingent': None, 'is_price_reduced': False, 'is_pending': None, 'is_foreclosure': None, 'is_plan': None, 'is_coming_soon': None, 'is_new_listing': False}, 'community': None, 'products': {'brand_name': 'basic_opt_in'}, 'virtual_tours': None, 'other_listings': {'rdc': [{'listing_id': '2957241843', 'listing_key': None, 'status': 'sold', 'primary': True}, {'listing_id': '2957022863', 'listing_key': None, 'status': 'off_market', 'primary': None}]}, 'listing_id': '2957241843', 'price_reduced_amount': 45000, 'location': {'address': {'postal_code': '99801', 'state': 'Alaska', 'coordinate': {'lon': -134.59372, 'lat': 58.36395}, 'city': 'Juneau', 'state_code': 'AK', 'line': '9453 Herbert Pl'}, 'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9453%20Herbert%20Pl%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=OPv224SjFIJWgVKAXZKZXNYEdNQ=', 'county': {'fips_code': None, 'name': 'Juneau'}}, 'matterport': False}, {'primary_photo': None, 'last_update_date': None, 'source': None, 'tags': None, 'permalink': '8477-Thunder-Mountain-Rd_Juneau_AK_99801_M94249-83842', 'status': 'sold', 'list_date': None, 'open_houses': None, 'description': {'year_built': None, 'baths_3qtr': None, 'sold_date': '2023-08-22', 'sold_price': None, 'baths_full': None, 'name': None, 'baths_half': None, 'lot_sqft': None, 'sqft': None, 'baths': None, 'sub_type': None, 'baths_1qtr': None, 'garage': None, 'stories': None, 'beds': None, 'type': None}, 'branding': [{'name': None, 'photo': None, 'type': 'Office'}], 'list_price': None, 'lead_attributes': {'show_contact_an_agent': T ...
# <class 'dict'>

# %%
# load type of data and attributes of one file

# local JSON file
file_path = '../data/AK_Juneau_0.json'
with open(file_path, 'r') as f:
    data = json.load(f) 
    print(json.dumps(data, indent=4))

#attribute of data
print(type(data))
# Out:
# {
#     "status": 200,
#     "data": {
#         "total": 8,
#         "count": 8,
#         "results": [
#             {
#                 "primary_photo": {
#                     "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#                 },
#                 "last_update_date": "2023-09-19T20:52:50Z",
#                 "source": {
#                     "plan_id": null,
#                     "agents": [
#                         {
#                             "office_name": "EXP Realty LLC - Southeast Alaska"
#                         },
#                         {
#                             "office_name": "Non-Member Office"
#                         }
#                     ],
#                     "spec_id": null,
#                     "type": "mls"
#                 },
#                 "tags": [
#                     "carport",
#                     "community_outdoor_space",
#                     "cul_de_sac",
#                     "family_room",
#                     "hardwood_floors",
#                     "hill_or_mountain_view",
#                     "recreation_facilities",
#                     "rv_or_boat_parking",
#                     "basement",
#                     "garage_1_or_more",
#                     "two_or_more_stories",
#                     "big_yard",
#                     "high_ceiling",
#                     "efficient",
#                     "trails",
#                     "shopping"
#                 ],
#                 "permalink": "9453-Herbert-Pl_Juneau_AK_99801_M90744-30767",
#                 "status": "sold",
#                 "list_date": "2023-06-29T21:16:25.000000Z",
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 1963,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-09-18",
#                     "sold_price": null,
#                     "baths_full": 2,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": 10454,
#                     "sqft": 1821,
#                     "baths": 2,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": 1,
#                     "stories": null,
#                     "beds": 3,
#                     "type": "single_family"
#                 },
#                 "branding": [
#                     {
#                         "name": "EXP Realty LLC - Southeast Alaska",
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": 554950,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9074430767",
#                 "photos": [
#                     {
#                         "tags": [
#                             {
#                                 "label": "house_view",
#                                 "probability": 0.9931892156601
#                             },
#                             {
#                                 "label": "road_view",
#                                 "probability": 0.84215885400772
#                             },
#                             {
#                                 "label": "house_view",
#                                 "probability": 0.93829786777496
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "living_room",
#                                 "probability": 0.99856203794479
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2021977128s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "dining_room",
#                                 "probability": 0.99998116493225
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2832281708s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "unknown",
#                                 "probability": 0.91968685388565
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2250208436s-w1024_h768.jpg"
#                     },
#                     {
#                         "tags": [
#                             {
#                                 "label": "kitchen",
#                                 "probability": 0.99999892711639
#                             }
#                         ],
#                         "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m4264543754s-w1024_h768.jpg"
#                     }
#                 ],
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": false,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": false
#                 },
#                 "community": null,
#                 "products": {
#                     "brand_name": "basic_opt_in"
#                 },
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2957241843",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": true
#                         },
#                         {
#                             "listing_id": "2957022863",
#                             "listing_key": null,
#                             "status": "off_market",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": "2957241843",
#                 "price_reduced_amount": 45000,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.59372,
#                             "lat": 58.36395
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "9453 Herbert Pl"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9453%20Herbert%20Pl%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=OPv224SjFIJWgVKAXZKZXNYEdNQ=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "8477-Thunder-Mountain-Rd_Juneau_AK_99801_M94249-83842",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-22",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9424983842",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958935271",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "8477 Thunder Mountain Rd"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=8477%20Thunder%20Mountain%20Rd%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=X_IwZxbWaAsrSLHsERLq_64YJhc=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "4515-Glacier-Hwy_Juneau_AK_99801_M94790-68516",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-22",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9479068516",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958935192",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "4515 Glacier Hwy"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4515%20Glacier%20Hwy%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=ql3QFXXYvrKARTE42MC9p2Egtdg=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "17850-Point-Stephens-Rd_Juneau_AK_99801_M98793-31943",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-21",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9879331943",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958925235",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "17850 Point Stephens Rd"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=17850%20Point%20Stephens%20Rd%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=sSYpYLhHnOQYJTloXVnGAmy2ydY=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": null,
#                 "source": null,
#                 "tags": null,
#                 "permalink": "9951-Stephen-Richards-Memorial-Dr_Juneau_AK_99801_M95216-39574",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": null,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-21",
#                     "sold_price": null,
#                     "baths_full": null,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": null,
#                     "baths": null,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": null,
#                     "type": null
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "9521639574",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958924367",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": null,
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "9951 Stephen Richards Memorial Dr"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9951%20Stephen%20Richards%20Memorial%20Dr%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=al_a0xZ7J3DLCuNg4YDdfq3TZKE=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": "2023-08-04T22:49:14Z",
#                 "source": {
#                     "plan_id": null,
#                     "agents": [
#                         {
#                             "office_name": "Platinum Keller Williams Realty Alaska Group"
#                         },
#                         {
#                             "office_name": "Platinum Keller Williams Realty Alaska Group"
#                         }
#                     ],
#                     "spec_id": null,
#                     "type": "mls"
#                 },
#                 "tags": [
#                     "carport",
#                     "hill_or_mountain_view",
#                     "ocean_view",
#                     "single_story",
#                     "waterfront",
#                     "open_floor_plan",
#                     "floor_plan",
#                     "rental_property",
#                     "furniture",
#                     "new_roof",
#                     "beach"
#                 ],
#                 "permalink": "11909-Glacier-Hwy-Apt-105_Juneau_AK_99801_M74123-09719",
#                 "status": "sold",
#                 "list_date": "2023-08-21T21:01:22.000000Z",
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 1969,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-04",
#                     "sold_price": null,
#                     "baths_full": 1,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": null,
#                     "sqft": 950,
#                     "baths": 1,
#                     "sub_type": "condo",
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": null,
#                     "beds": 2,
#                     "type": "condos"
#                 },
#                 "branding": [
#                     {
#                         "name": "Platinum Keller Williams Realty Alaska Group",
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": 415000,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "7412309719",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": false
#                 },
#                 "community": null,
#                 "products": {
#                     "brand_name": "basic_opt_in"
#                 },
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958925334",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": "2958925334",
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.649067,
#                             "lat": 58.386651
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "11909 Glacier Hwy Apt 105"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=11909%20Glacier%20Hwy%20Apt%20105%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=cokn0o0X46-BL_yReSTViMXMYh4=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": "2023-08-04T21:31:44Z",
#                 "source": {
#                     "plan_id": null,
#                     "agents": [
#                         {
#                             "office_name": "Southeast Alaska Real Estate"
#                         },
#                         {
#                             "office_name": "Platinum Keller Williams Realty Alaska Group"
#                         }
#                     ],
#                     "spec_id": null,
#                     "type": "mls"
#                 },
#                 "tags": [
#                     "city_view",
#                     "community_outdoor_space",
#                     "community_security_features",
#                     "corner_lot",
#                     "hill_or_mountain_view",
#                     "lake_view",
#                     "ocean_view",
#                     "river_view",
#                     "spa_or_hot_tub",
#                     "garage_1_or_more",
#                     "garage_2_or_more",
#                     "two_or_more_stories",
#                     "vaulted_ceiling",
#                     "media_room",
#                     "ensuite",
#                     "private_courtyard",
#                     "trails"
#                 ],
#                 "permalink": "808-5th-St_Juneau_AK_99801_M76604-90777",
#                 "status": "sold",
#                 "list_date": "2023-08-21T21:01:22.000000Z",
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 1920,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-08-03",
#                     "sold_price": null,
#                     "baths_full": 3,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": 5875,
#                     "sqft": 3860,
#                     "baths": 3,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": 2,
#                     "stories": null,
#                     "beds": 5,
#                     "type": "single_family"
#                 },
#                 "branding": [
#                     {
#                         "name": "Southeast Alaska Real Estate",
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": 835000,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "7660490777",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": false
#                 },
#                 "community": null,
#                 "products": {
#                     "brand_name": "essentials"
#                 },
#                 "virtual_tours": null,
#                 "other_listings": {
#                     "rdc": [
#                         {
#                             "listing_id": "2958924095",
#                             "listing_key": null,
#                             "status": "sold",
#                             "primary": null
#                         },
#                         {
#                             "listing_id": "2941727948",
#                             "listing_key": null,
#                             "status": "off_market",
#                             "primary": null
#                         },
#                         {
#                             "listing_id": "2641864483",
#                             "listing_key": null,
#                             "status": "off_market",
#                             "primary": null
#                         }
#                     ]
#                 },
#                 "listing_id": "2958924095",
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.403991,
#                             "lat": 58.304573
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "808 5th St"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=808%205th%20St%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=tV-uGGz9zKJiafcI3GDfgu9GV_I=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             },
#             {
#                 "primary_photo": null,
#                 "last_update_date": "2023-12-07",
#                 "source": null,
#                 "tags": null,
#                 "permalink": "4446-Trafalgar-Ave_Juneau_AK_99801_M82741-21172",
#                 "status": "sold",
#                 "list_date": null,
#                 "open_houses": null,
#                 "description": {
#                     "year_built": 2002,
#                     "baths_3qtr": null,
#                     "sold_date": "2023-07-21",
#                     "sold_price": null,
#                     "baths_full": 2,
#                     "name": null,
#                     "baths_half": null,
#                     "lot_sqft": 7476,
#                     "sqft": 1375,
#                     "baths": 2,
#                     "sub_type": null,
#                     "baths_1qtr": null,
#                     "garage": null,
#                     "stories": 1,
#                     "beds": 3,
#                     "type": "mobile"
#                 },
#                 "branding": [
#                     {
#                         "name": null,
#                         "photo": null,
#                         "type": "Office"
#                     }
#                 ],
#                 "list_price": null,
#                 "lead_attributes": {
#                     "show_contact_an_agent": true
#                 },
#                 "property_id": "8274121172",
#                 "photos": null,
#                 "flags": {
#                     "is_new_construction": null,
#                     "is_for_rent": null,
#                     "is_subdivision": null,
#                     "is_contingent": null,
#                     "is_price_reduced": null,
#                     "is_pending": null,
#                     "is_foreclosure": null,
#                     "is_plan": null,
#                     "is_coming_soon": null,
#                     "is_new_listing": null
#                 },
#                 "community": null,
#                 "products": null,
#                 "virtual_tours": null,
#                 "other_listings": null,
#                 "listing_id": null,
#                 "price_reduced_amount": null,
#                 "location": {
#                     "address": {
#                         "postal_code": "99801",
#                         "state": "Alaska",
#                         "coordinate": {
#                             "lon": -134.553717,
#                             "lat": 58.396178
#                         },
#                         "city": "Juneau",
#                         "state_code": "AK",
#                         "line": "4446 Trafalgar Ave"
#                     },
#                     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4446%20Trafalgar%20Ave%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=V24OM91aZHY5-heG-dKObuuYh4c=",
#                     "county": {
#                         "fips_code": null,
#                         "name": "Juneau"
#                     }
#                 },
#                 "matterport": false
#             }
#         ]
#     }
# }
# <class 'dict'>

# %%
print(data['data'].keys())  # subkeys under 'data' in single file
# Out:
# dict_keys(['total', 'count', 'results'])

# %%
#single item results list
results = data['data']['results']
print(type(results))           
print(len(results))            # listings
print(results[0].keys())       # Keys in first listing
print(json.dumps(results[0], indent=2))  # first result
# Out:
# <class 'list'>
# 8
# dict_keys(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink', 'status', 'list_date', 'open_houses', 'description', 'branding', 'list_price', 'lead_attributes', 'property_id', 'photos', 'flags', 'community', 'products', 'virtual_tours', 'other_listings', 'listing_id', 'price_reduced_amount', 'location', 'matterport'])
# {
#   "primary_photo": {
#     "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#   },
#   "last_update_date": "2023-09-19T20:52:50Z",
#   "source": {
#     "plan_id": null,
#     "agents": [
#       {
#         "office_name": "EXP Realty LLC - Southeast Alaska"
#       },
#       {
#         "office_name": "Non-Member Office"
#       }
#     ],
#     "spec_id": null,
#     "type": "mls"
#   },
#   "tags": [
#     "carport",
#     "community_outdoor_space",
#     "cul_de_sac",
#     "family_room",
#     "hardwood_floors",
#     "hill_or_mountain_view",
#     "recreation_facilities",
#     "rv_or_boat_parking",
#     "basement",
#     "garage_1_or_more",
#     "two_or_more_stories",
#     "big_yard",
#     "high_ceiling",
#     "efficient",
#     "trails",
#     "shopping"
#   ],
#   "permalink": "9453-Herbert-Pl_Juneau_AK_99801_M90744-30767",
#   "status": "sold",
#   "list_date": "2023-06-29T21:16:25.000000Z",
#   "open_houses": null,
#   "description": {
#     "year_built": 1963,
#     "baths_3qtr": null,
#     "sold_date": "2023-09-18",
#     "sold_price": null,
#     "baths_full": 2,
#     "name": null,
#     "baths_half": null,
#     "lot_sqft": 10454,
#     "sqft": 1821,
#     "baths": 2,
#     "sub_type": null,
#     "baths_1qtr": null,
#     "garage": 1,
#     "stories": null,
#     "beds": 3,
#     "type": "single_family"
#   },
#   "branding": [
#     {
#       "name": "EXP Realty LLC - Southeast Alaska",
#       "photo": null,
#       "type": "Office"
#     }
#   ],
#   "list_price": 554950,
#   "lead_attributes": {
#     "show_contact_an_agent": true
#   },
#   "property_id": "9074430767",
#   "photos": [
#     {
#       "tags": [
#         {
#           "label": "house_view",
#           "probability": 0.9931892156601
#         },
#         {
#           "label": "road_view",
#           "probability": 0.84215885400772
#         },
#         {
#           "label": "house_view",
#           "probability": 0.93829786777496
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2867511255s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "living_room",
#           "probability": 0.99856203794479
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2021977128s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "dining_room",
#           "probability": 0.99998116493225
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2832281708s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "unknown",
#           "probability": 0.91968685388565
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m2250208436s-w1024_h768.jpg"
#     },
#     {
#       "tags": [
#         {
#           "label": "kitchen",
#           "probability": 0.99999892711639
#         }
#       ],
#       "href": "https://ap.rdcpix.com/07097d34c98a59ebb799688986ef271dl-m4264543754s-w1024_h768.jpg"
#     }
#   ],
#   "flags": {
#     "is_new_construction": null,
#     "is_for_rent": null,
#     "is_subdivision": null,
#     "is_contingent": null,
#     "is_price_reduced": false,
#     "is_pending": null,
#     "is_foreclosure": null,
#     "is_plan": null,
#     "is_coming_soon": null,
#     "is_new_listing": false
#   },
#   "community": null,
#   "products": {
#     "brand_name": "basic_opt_in"
#   },
#   "virtual_tours": null,
#   "other_listings": {
#     "rdc": [
#       {
#         "listing_id": "2957241843",
#         "listing_key": null,
#         "status": "sold",
#         "primary": true
#       },
#       {
#         "listing_id": "2957022863",
#         "listing_key": null,
#         "status": "off_market",
#         "primary": null
#       }
#     ]
#   },
#   "listing_id": "2957241843",
#   "price_reduced_amount": 45000,
#   "location": {
#     "address": {
#       "postal_code": "99801",
#       "state": "Alaska",
#       "coordinate": {
#         "lon": -134.59372,
#         "lat": 58.36395
#       },
#       "city": "Juneau",
#       "state_code": "AK",
#       "line": "9453 Herbert Pl"
#     },
#     "street_view_url": "https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9453%20Herbert%20Pl%2C%20Juneau%2C%20AK%2099801&size=640x480&source=outdoor&signature=OPv224SjFIJWgVKAXZKZXNYEdNQ=",
#     "county": {
#       "fips_code": null,
#       "name": "Juneau"
#     }
#   },
#   "matterport": false
# }

# %%
#diagnostic workflow 
with open('../data/AK_Juneau_0.json') as f:
    data = json.load(f)

print(data.keys())
print(data['data'].keys())
print(type(data['data']['results']))     # should be list
print(data['data']['results'][0].keys()) # first result fields
# Out:
# dict_keys(['status', 'data'])
# dict_keys(['total', 'count', 'results'])
# <class 'list'>
# dict_keys(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink', 'status', 'list_date', 'open_houses', 'description', 'branding', 'list_price', 'lead_attributes', 'property_id', 'photos', 'flags', 'community', 'products', 'virtual_tours', 'other_listings', 'listing_id', 'price_reduced_amount', 'location', 'matterport'])

# %%
#all json files, including one file, into dataframe; loop through each file, extract results, convert to DF

# Path to your JSON files
data_folder = '../data'

# List all JSON files
json_files = [f for f in os.listdir(data_folder) if f.endswith('.json')]

# Store all rows from all files
all_results = []

# Loop through each file
for filename in json_files:
    file_path = os.path.join(data_folder, filename)

    with open(file_path, 'r') as f:
        data = json.load(f)

    # Safely get the list of results
    results = data.get('data', {}).get('results', [])
    
    # Append each result to the master list
    all_results.extend(results)

# Convert the full list of results to a DataFrame
df = pd.DataFrame(all_results)

# Preview
print(df.shape)
print(df.head())
# Out:
# (8159, 23)
#                                        primary_photo      last_update_date  \
# 0  {'href': 'https://ap.rdcpix.com/8c0b391ae4f9bb...  2024-01-17T00:01:55Z
# 1  {'href': 'https://ap.rdcpix.com/40c55dc5d4e29a...  2024-01-16T16:49:36Z
# 2  {'href': 'https://ap.rdcpix.com/497a833c1c423b...  2024-01-13T00:03:39Z
# 3  {'href': 'https://ap.rdcpix.com/ade15664a2e839...  2024-01-16T07:48:30Z
# 4  {'href': 'https://ap.rdcpix.com/a5dada323a7e61...  2024-01-13T00:01:45Z
#
#                                               source  \
# 0  {'plan_id': None, 'agents': [{'office_name': N...
# 1  {'plan_id': None, 'agents': [{'office_name': N...
# 2  {'plan_id': None, 'agents': [{'office_name': N...
# 3  {'plan_id': None, 'agents': [{'office_name': N...
# 4  {'plan_id': None, 'agents': [{'office_name': N...
#
#                                                 tags  \
# 0  [central_air, dishwasher, fireplace, forced_ai...
# 1  [disability_features, basement, garage_1_or_mo...
# 2  [carport, central_air, dishwasher, fireplace, ...
# 3  [central_air, dining_room, disability_features...
# 4           [dining_room, hardwood_floors, basement]
#
#                                           permalink status  \
# 0   1869-Pebble-Ct_Harrisburg_PA_17110_M33009-59879   sold
# 1    3100-N-3rd-St_Harrisburg_PA_17110_M31492-47078   sold
# 2   7551-Davids-Rd_Harrisburg_PA_17111_M46860-76173   sold
# 3      2722-Bur-Ct_Harrisburg_PA_17112_M40850-14275   sold
# 4  404-Crescent-St_Harrisburg_PA_17104_M37433-85520   sold
#
#                      list_date open_houses  \
# 0  2023-11-27T05:15:07.000000Z        None
# 1  2023-11-23T11:38:45.000000Z        None
# 2  2023-12-16T02:39:18.000000Z        None
# 3  2023-10-24T14:15:02.000000Z        None
# 4  2023-11-15T17:43:35.000000Z        None
#
#                                          description  \
# 0  {'year_built': 2001, 'baths_3qtr': None, 'sold...
# 1  {'year_built': 1900, 'baths_3qtr': None, 'sold...
# 2  {'year_built': 1971, 'baths_3qtr': None, 'sold...
# 3  {'year_built': 2013, 'baths_3qtr': None, 'sold...
# 4  {'year_built': 1900, 'baths_3qtr': None, 'sold...
#
#                                             branding  ...  \
# 0  [{'name': 'Howard Hanna - Colonial Park', 'pho...  ...
# 1  [{'name': 'Camp Hill', 'photo': None, 'type': ...  ...
# 2  [{'name': 'Coldwell Banker Realty', 'photo': N...  ...
# 3  [{'name': 'Iron Valley Real Estate Of Central ...  ...
# 4  [{'name': 'Camp Hill', 'photo': None, 'type': ...  ...
#
#                                               photos  \
# 0  [{'tags': [{'label': 'garage', 'probability': ...
# 1  [{'tags': [{'label': 'house_view', 'probabilit...
# 2  [{'tags': [{'label': 'house_view', 'probabilit...
# 3  [{'tags': [{'label': 'unknown', 'probability':...
# 4  [{'tags': [{'label': 'unknown', 'probability':...
#
#                                                flags community  \
# 0  {'is_new_construction': None, 'is_for_rent': N...      None
# 1  {'is_new_construction': None, 'is_for_rent': N...      None
# 2  {'is_new_construction': None, 'is_for_rent': N...      None
# 3  {'is_new_construction': None, 'is_for_rent': N...      None
# 4  {'is_new_construction': None, 'is_for_rent': N...      None
#
#                        products virtual_tours  \
# 0  {'brand_name': 'essentials'}          None
# 1  {'brand_name': 'essentials'}          None
# 2  {'brand_name': 'essentials'}          None
# 3  {'brand_name': 'essentials'}          None
# 4  {'brand_name': 'essentials'}          None
#
#                                       other_listings  listing_id  \
# 0  {'rdc': [{'listing_id': '2961973062', 'listing...  2961973062
# 1  {'rdc': [{'listing_id': '2961936671', 'listing...  2961936671
# 2  {'rdc': [{'listing_id': '2962590916', 'listing...  2962590916
# 3  {'rdc': [{'listing_id': '2960823390', 'listing...  2960823390
# 4  {'rdc': [{'listing_id': '612007585', 'listing_...  2961699518
#
#   price_reduced_amount                                           location  \
# 0                  NaN  {'address': {'postal_code': '17110', 'state': ...
# 1                  NaN  {'address': {'postal_code': '17110', 'state': ...
# 2                  NaN  {'address': {'postal_code': '17111', 'state': ...
# 3                  NaN  {'address': {'postal_code': '17112', 'state': ...
# 4                  NaN  {'address': {'postal_code': '17104', 'state': ...
#
#   matterport
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink',
#        'status', 'list_date', 'open_houses', 'description', 'branding',
#        'list_price', 'lead_attributes', 'property_id', 'photos', 'flags',
#        'community', 'products', 'virtual_tours', 'other_listings',
#        'listing_id', 'price_reduced_amount', 'location', 'matterport'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning and Wrangling

# %% [markdown]
# At this point, ensure that you have all sales in a dataframe.
# - Take a quick look at your data (i.e. `.info()`, `.describe()`) - what do you see?
# - Is each cell one value, or do some cells have lists?
# - What are the data types of each column?
# - Some sales may not actually include the sale price (target).  These rows should be dropped.
# - There are a lot of NA/None values.  Should these be dropped or replaced with something?
#     - You can drop rows or use various methods to fills NA's - use your best judgement for each column
#     - i.e. for some columns (like Garage), NA probably just means no Garage, so 0
# - Drop columns that aren't needed
#     - Don't keep the list price because it will be too close to the sale price. Assume we want to predict the price of houses not yet listed

# %%
# load and concatenate data here
# drop or replace values as necessary

# %%
df = pd.DataFrame(all_results)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8159 entries, 0 to 8158
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   primary_photo         7403 non-null   object
#  1   last_update_date      8125 non-null   object
#  2   source                7752 non-null   object
#  3   tags                  7638 non-null   object
#  4   permalink             8159 non-null   object
#  5   status                8159 non-null   object
#  6   list_date             7752 non-null   object
#  7   open_houses           0 non-null      object
#  8   description           8159 non-null   object
#  9   branding              8159 non-null   object
#  10  list_price            7721 non-null   float64
#  11  lead_attributes       8159 non-null   object
#  12  property_id           8159 non-null   object
#  13  photos                7403 non-null   object
#  14  flags                 8159 non-null   object
#  15  community             5 non-null      object
#  16  products              7673 non-null   object
#  17  virtual_tours         1351 non-null   object
#  18  other_listings        7856 non-null   object
#  19  listing_id            7752 non-null   object
#  20  price_reduced_amount  2484 non-null   float64
#  21  location              8159 non-null   object
#  22  matterport            8159 non-null   bool
# dtypes: bool(1), float64(2), object(20)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (8159, 23)

# %%
df.describe(include='all')
# Out:
#                                             primary_photo last_update_date  \
# count                                                7403             8125
# unique                                               1627             1716
# top     {'href': 'https://ap.rdcpix.com/6a9d57d5c31e4f...       2023-10-20
# freq                                                    5               95
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                                                    source       tags  \
# count                                                7752       7638
# unique                                                393       1628
# top     {'plan_id': None, 'agents': [{'office_name': N...  [big_lot]
# freq                                                 5127         62
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#                                                 permalink status  \
# count                                                8159   8159
# unique                                               1795      1
# top     12312-Birchfalls-Dr_Raleigh_NC_27614_M60077-26455   sold
# freq                                                    5   8159
# mean                                                  NaN    NaN
# std                                                   NaN    NaN
# min                                                   NaN    NaN
# 25%                                                   NaN    NaN
# 50%                                                   NaN    NaN
# 75%                                                   NaN    NaN
# max                                                   NaN    NaN
#
#                           list_date open_houses  \
# count                          7752           0
# unique                         1636           0
# top     2024-01-05T17:38:27.000000Z         NaN
# freq                             80         NaN
# mean                            NaN         NaN
# std                             NaN         NaN
# min                             NaN         NaN
# 25%                             NaN         NaN
# 50%                             NaN         NaN
# 75%                             NaN         NaN
# max                             NaN         NaN
#
#                                               description  \
# count                                                8159
# unique                                               1791
# top     {'year_built': None, 'baths_3qtr': None, 'sold...
# freq                                                   10
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  branding  ...  \
# count                                                8159  ...
# unique                                                996  ...
# top     [{'name': None, 'photo': None, 'type': 'Office'}]  ...
# freq                                                  434  ...
# mean                                                  NaN  ...
# std                                                   NaN  ...
# min                                                   NaN  ...
# 25%                                                   NaN  ...
# 50%                                                   NaN  ...
# 75%                                                   NaN  ...
# max                                                   NaN  ...
#
#                                                    photos  \
# count                                                7403
# unique                                               1627
# top     [{'tags': [{'label': 'unknown', 'probability':...
# freq                                                    5
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     flags  \
# count                                                8159
# unique                                                  6
# top     {'is_new_construction': None, 'is_for_rent': N...
# freq                                                 5231
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 community  \
# count                                                   5
# unique                                                  1
# top     {'advertisers': [{'office': {'hours': 'Monday ...
# freq                                                    5
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                             products  \
# count                           7673
# unique                             4
# top     {'brand_name': 'essentials'}
# freq                            4900
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
#                                             virtual_tours  \
# count                                                1351
# unique                                                290
# top     [{'type': None, 'href': 'https://cambiomhc.com...
# freq                                                   20
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            other_listings  listing_id  \
# count                                                7856        7752
# unique                                               1726        1704
# top     {'rdc': [{'listing_id': '2961896671', 'listing...  2954807059
# freq                                                    5           5
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#        price_reduced_amount  \
# count          2.484000e+03
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean           2.442704e+04
# std            7.162396e+04
# min            1.000000e+02
# 25%            6.000000e+03
# 50%            1.010000e+04
# 75%            2.000000e+04
# max            2.015999e+06
#
#                                                  location matterport
# count                                                8159       8159
# unique                                               1794          2
# top     {'address': {'postal_code': '50036', 'state': ...      False
# freq                                                    7       7830
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
# [11 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['primary_photo', 'last_update_date', 'source', 'tags', 'permalink',
#        'status', 'list_date', 'open_houses', 'description', 'branding',
#        'list_price', 'lead_attributes', 'property_id', 'photos', 'flags',
#        'community', 'products', 'virtual_tours', 'other_listings',
#        'listing_id', 'price_reduced_amount', 'location', 'matterport'],
#       dtype='object')

# %%
# cell value; false = cell does not contain list, true = cell contains list
df = pd.DataFrame(all_results)

# check if each cell contains a list
is_list = df.map(lambda x: isinstance(x, list))

# result
print(is_list)
# Out:
#       primary_photo  last_update_date  source   tags  permalink  status  \
# 0             False             False   False   True      False   False
# 1             False             False   False   True      False   False
# 2             False             False   False   True      False   False
# 3             False             False   False   True      False   False
# 4             False             False   False   True      False   False
# ...             ...               ...     ...    ...        ...     ...
# 8154          False             False   False  False      False   False
# 8155          False             False   False   True      False   False
# 8156          False             False   False   True      False   False
# 8157          False             False   False   True      False   False
# 8158          False             False   False   True      False   False
#
#       list_date  open_houses  description  branding  ...  photos  flags  \
# 0         False        False        False      True  ...    True  False
# 1         False        False        False      True  ...    True  False
# 2         False        False        False      True  ...    True  False
# 3         False        False        False      True  ...    True  False
# 4         False        False        False      True  ...    True  False
# ...         ...          ...          ...       ...  ...     ...    ...
# 8154      False        False        False      True  ...   False  False
# 8155      False        False        False      True  ...    True  False
# 8156      False        False        False      True  ...    True  False
# 8157      False        False        False      True  ...    True  False
# 8158      False        False        False      True  ...   False  False
#
#       community  products  virtual_tours  other_listings  listing_id  \
# 0         False     False          False           False       False
# 1         False     False          False           False       False
# 2         False     False          False           False       False
# 3         False     False          False           False       False
# 4         False     False          False           False       False
# ...         ...       ...            ...             ...         ...
# 8154      False     False          False           False       False
# 8155      False     False          False           False       False
# 8156      False     False           True           False       False
# 8157      False     False           True           False       False
# 8158      False     False          False           False       False
#
#       price_reduced_amount  location  matterport
# 0                    False     False       False
# 1                    False     False       False
# 2                    False     False       False
# 3                    False     False       False
# 4                    False     False       False
# ...                    ...       ...         ...
# 8154                 False     False       False
# 8155                 False     False       False
# 8156                 False     False       False
# 8157                 False     False       False
# 8158                 False     False       False
#
# [8159 rows x 23 columns]

# %%
#sold price print - keep for reference re drop list price 

for index, row in df.iterrows():
    print(f"Row {index} - Sold Price: {row['description'].get('sold_price', 'Not Available')}")
# Out:
# Row 0 - Sold Price: 345000
# Row 1 - Sold Price: 196000
# Row 2 - Sold Price: 205000
# Row 3 - Sold Price: 295000
# Row 4 - Sold Price: 106000
# Row 5 - Sold Price: 10000
# Row 6 - Sold Price: 71500
# Row 7 - Sold Price: 100000
# Row 8 - Sold Price: 208000
# Row 9 - Sold Price: 28000
# Row 10 - Sold Price: 346000
# Row 11 - Sold Price: 219900
# Row 12 - Sold Price: 195000
# Row 13 - Sold Price: 270000
# Row 14 - Sold Price: 180000
# Row 15 - Sold Price: 232000
# Row 16 - Sold Price: 58000
# Row 17 - Sold Price: 275000
# Row 18 - Sold Price: 242000
# Row 19 - Sold Price: 241500
# Row 20 - Sold Price: 350000
# Row 21 - Sold Price: 274500
# Row 22 - Sold Price: 107000
# Row 23 - Sold Price: 237000
# Row 24 - Sold Price: 305000
# Row 25 - Sold Price: 229000
# Row 26 - Sold Price: 225000
# Row 27 - Sold Price: 200000
# Row 28 - Sold Price: 30000
# Row 29 - Sold Price: 427900
# Row 30 - Sold Price: 200000
# Row 31 - Sold Price: 225000
# Row 32 - Sold Price: 225000
# Row 8139 - Sold Price: 143500
# Row 8140 - Sold Price: 165900
# Row 8141 - Sold Price: 530000
# Row 8142 - Sold Price: 145000
# Row 8143 - Sold Price: 236000
# Row 8144 - Sold Price: 162000
# Row 8145 - Sold Price: 265000
# Row 8146 - Sold Price: 158000
# Row 8147 - Sold Price: 240000
# Row 8148 - Sold Price: 322000
# Row 8149 - Sold Price: 235000
# Row 8150 - Sold Price: 294988
# Row 8151 - Sold Price: 676860
# Row 8152 - Sold Price: 300000
# Row 8153 - Sold Price: 330000
# Row 8154 - Sold Price: 349990
# Row 8155 - Sold Price: 140000
# Row 8156 - Sold Price: 210000
# Row 8157 - Sold Price: 163000
# Row 8158 - Sold Price: 655000

# %% [markdown]
# ### Dealing with Tags

# %% [markdown]
# Consider the fact that with tags, there are a lot of categorical variables.
# - How many columns would we have if we OHE tags, city and state?
# - Perhaps we can get rid of tags that have a low frequency.

# %%
# Extract city and state from location
df['city'] = df['location'].apply(lambda x: x.get('address', {}).get('city') if isinstance(x, dict) else None)
df['state'] = df['location'].apply(lambda x: x.get('address', {}).get('state') if isinstance(x, dict) else None)

# Clean tags column to ensure lists
df['tags'] = df['tags'].apply(lambda x: x if isinstance(x, list) else [])

# Count all tags
all_tags = [tag for tags in df['tags'] for tag in tags]
tag_counts = Counter(all_tags)

# Unique counts for city and state
unique_cities = df['city'].nunique()
unique_states = df['state'].nunique()

# Filter tags with more than 10 occurrences
frequent_tags = [tag for tag, count in tag_counts.items() if count > 10]

print(f"Unique cities: {unique_cities}")
print(f"Unique states: {unique_states}")
print(f"Total unique tags: {len(tag_counts)}")
print(f"Frequent tags (>10 occurrences): {len(frequent_tags)}")

# Estimate total OHE columns: city + state + filtered tags
total_ohe_columns = unique_cities + unique_states + len(frequent_tags)
print(f"Estimated total OHE columns: {total_ohe_columns}")
# Out:
# Unique cities: 101
# Unique states: 45
# Total unique tags: 155
# Frequent tags (>10 occurrences): 142
# Estimated total OHE columns: 288

# %%
# Define frequency threshold for city/state
city_threshold = 5
state_threshold = 5

# Count city and state occurrences
city_counts = df['city'].value_counts()
state_counts = df['state'].value_counts()

# Replace rare cities/states with 'Other'
df['city'] = df['city'].apply(lambda x: x if city_counts.get(x, 0) > city_threshold else 'Other')
df['state'] = df['state'].apply(lambda x: x if state_counts.get(x, 0) > state_threshold else 'Other')

# After replacement, recount unique cities/states
unique_cities = df['city'].nunique()
unique_states = df['state'].nunique()

print(f"Unique cities after merging rare: {unique_cities}")
print(f"Unique states after merging rare: {unique_states}")
# Out:
# Unique cities after merging rare: 64
# Unique states after merging rare: 45

# %%
import matplotlib.pyplot as plt

# Get tag counts as a list
tag_count_values = list(tag_counts.values())

plt.figure(figsize=(10,6))
plt.hist(tag_count_values, bins=30, edgecolor='black')
plt.title('Tag Frequency Distribution')
plt.xlabel('Number of Occurrences')
plt.ylabel('Number of Tags')
plt.grid(axis='y')
plt.show()

# %%
freq_threshold = 20
frequent_tags = [tag for tag, count in tag_counts.items() if count > freq_threshold]
print(f"Frequent tags (>20 occurrences): {len(frequent_tags)}")

total_ohe_columns = unique_cities + unique_states + len(frequent_tags)
print(f"Estimated total OHE columns after merging rare cities/states and threshold 20 tags: {total_ohe_columns}")
# Out:
# Frequent tags (>20 occurrences): 134
# Estimated total OHE columns after merging rare cities/states and threshold 20 tags: 243

# %% [markdown]
# ### Dealing with Cities
#
#
# - Sales will vary drastically between cities and states.  Is there a way to keep information about which city it is without OHE?
# - Could we label encode or ordinal encode?  Yes, but this may have undesirable effects, giving nominal data ordinal values.
# - What we can do is use our training data to encode the mean sale price by city as a feature (a.k.a. Target Encoding)
#     - We can do this as long as we ONLY use the training data - we're using the available data to give us a 'starting guess' of the price for each city, without needing to encode city explicitly
# - If you replace cities or states with numerical values (like the mean price), make sure that the data is split so that we don't leak data into the training selection. This is a great time to train test split. Compute on the training data, and join these values to the test data
# - Note that you *may* have cities in the test set that are not in the training set. You don't want these to be NA, so maybe you can fill them with the overall mean

# %%
from sklearn.model_selection import train_test_split

# Split data
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Compute mean price by city using training data
city_means = train_df.groupby('city')['list_price'].mean()

# Global mean to fill unknown cities
global_mean = train_df['list_price'].mean()

# Create the new encoded columns as separate Series
train_city_encoded = train_df['city'].map(city_means)
test_city_encoded = test_df['city'].map(city_means).fillna(global_mean)

# Combine using concat all at once
train_df = pd.concat([train_df, train_city_encoded.rename('city_encoded')], axis=1)
test_df = pd.concat([test_df, test_city_encoded.rename('city_encoded')], axis=1)

# Defragment by making a copy 
train_df = train_df.copy()
test_df = test_df.copy()

# %% [markdown]
# ## Extra Data - STRETCH
#
# > This doesn't need to be part of your Minimum Viable Product (MVP). We recommend you write a functional, basic pipeline first, then circle back and join new data if you have time
#
# > If you do this, try to write your downstream steps in a way it will still work on a dataframe with different features!
#
# - You're not limited to just using the data provided to you. Think/ do some research about other features that might be useful to predict housing prices.
# - Can you import and join this data? Make sure you do any necessary preprocessing and make sure it is joined correctly.
# - Example suggestion: could mortgage interest rates in the year of the listing affect the price?

# %%
# import, join and preprocess new data here

# %% [markdown]
# ## EDA/ Visualization
#
# Remember all of the EDA that you've been learning about?  Now is a perfect time for it!
# - Look at distributions of numerical variables to see the shape of the data and detect outliers.
#     - Consider transforming very skewed variables
# - Scatterplots of a numerical variable and the target go a long way to show correlations.
# - A heatmap will help detect highly correlated features, and we don't want these.
#     - You may have too many features to do this, in which case you can simply compute the most correlated feature-pairs and list them
# - Is there any overlap in any of the features? (redundant information, like number of this or that room...)

# %%
# Filter tags with absolute correlation > 0.1
threshold = 0.1
strong_corr_tags = tag_price_corr[ tag_price_corr.abs() > threshold ]

# Convert to DataFrame and sort
strong_corr_df = strong_corr_tags.to_frame(name='correlation').sort_values(by='correlation', ascending=False)

# Plot heatmap of filtered tags
plt.figure(figsize=(6, len(strong_corr_df) * 0.5))
sns.heatmap(strong_corr_df, annot=True, cmap='coolwarm', center=0)
plt.title(f'Tags with abs(correlation) > {threshold} to List Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scaling and Finishing Up

# %% [markdown]
# Now is a great time to scale the data and save it once it's preprocessed.
# - You can save it in your data folder, but you may want to make a new `processed/` subfolder to keep it organized
